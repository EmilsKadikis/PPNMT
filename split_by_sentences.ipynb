# %%
from indicnlp.tokenize import sentence_tokenize as sentence_tokenize_indic
import hasami

source_lang = "en"
target_lang = "ja"

sentencizer_source_language = "english"
sentencizer_target_language = "japanese"

split = "test"

if split == "train":
    domains = ["telephony", "topical_chat"]
elif split == "test":
    domains = ["telephony", "topical_chat", "call_center"]

# %%
from formality.data_loader import load_data

source_texts, target_texts_formal, _, _ = load_data(source_lang, target_lang, split, "all", "formal")
source_texts, target_texts_informal, _, _ = load_data(source_lang, target_lang, split, "all", "informal")
target_texts_formal_tagged, target_texts_informal_tagged = [], []

for domain in domains:
    base_path = f"./formality/CoCoA-MT/{split}/{source_lang}-{target_lang}/"
    tagged_formal_path = f"formality-control.{split}.{domain}.{source_lang}-{target_lang}.formal.annotated"
    if target_lang != "ja" and split == "train":
        tagged_formal_path += f".{target_lang}"
    tagged_informal_path = f"formality-control.{split}.{domain}.{source_lang}-{target_lang}.informal.annotated"
    if target_lang != "ja" and split == "train":
        tagged_informal_path += f".{target_lang}"
    with open(base_path + tagged_formal_path, "r") as f:
        for line in f:
            target_texts_formal_tagged.append(line.strip())
    with open(base_path + tagged_informal_path, "r") as f:
        for line in f:
            target_texts_informal_tagged.append(line.strip())

# %%
from nltk import tokenize

def split_into_sentences(text, sentencizer_language):
    if sentencizer_language == "hindi":
        sent_tokenize = lambda text : sentence_tokenize_indic.sentence_split(text, "hi")
    elif sentencizer_language == "japanese":
        sent_tokenize = hasami.segment_sentences
    else:
        sent_tokenize = lambda text : tokenize.sent_tokenize(text, sentencizer_language)
    if isinstance(text, list):
        sentencized_examples = []
        num_sentences = None
        for example in text:
            sentences = sent_tokenize(example)
            if isinstance(sentences, str):
                sentences = [sentences]
            sentencized_examples.append(sentences)
            if num_sentences is None:
                num_sentences = len(sentences)
            elif num_sentences != len(sentences):
                print("ERROR: Number of sentences in examples is not consistent.")
                print(text)
    
        return [[examples[i] for examples in sentencized_examples] for i in range(len(sentencized_examples[0]))]
    else:
        return sent_tokenize(text)

# %%
source_texts_new, target_texts_formal_new, target_texts_informal_new = [], [], []
target_texts_formal_tagged_new, target_texts_informal_tagged_new = [], []
bad_examples = []
for source, target_formal, target_informal, tagged_formal, tagged_informal in zip(source_texts, target_texts_formal, target_texts_informal, target_texts_formal_tagged, target_texts_informal_tagged):
    source_sentences = split_into_sentences(source, sentencizer_source_language)
    target_formal_sentences = split_into_sentences(target_formal, sentencizer_target_language)
    target_informal_sentences = split_into_sentences(target_informal, sentencizer_target_language)
    tagged_formal_sentences = split_into_sentences(tagged_formal, sentencizer_target_language)
    tagged_informal_sentences = split_into_sentences(tagged_informal, sentencizer_target_language)
    
    if len(source_sentences) == len(target_formal_sentences) == len(target_informal_sentences) == len(tagged_formal_sentences) == len(tagged_informal_sentences):
        source_texts_new.extend(source_sentences)
        target_texts_formal_new.extend(target_formal_sentences)
        target_texts_informal_new.extend(target_informal_sentences)
        target_texts_formal_tagged_new.extend(tagged_formal_sentences)
        target_texts_informal_tagged_new.extend(tagged_informal_sentences)
    else:
        bad_examples.append((source_sentences, target_formal_sentences, target_informal_sentences, tagged_formal_sentences, tagged_informal_sentences))
        print("Different number of sentences found in the following example:")
        print(source_sentences)
        print(target_formal_sentences)
        print(target_informal_sentences)
        print(tagged_formal_sentences)
        print(tagged_informal_sentences)
        print()

print("Number of bad examples:", len(bad_examples))
# Out:
# Different number of sentences found in the following example:
# ["but it is crazy, I can't get along with my family; in fact, they had a great Christmas this year, Christmas is really good.", 'You will be doing the holiday stuff']
# ['が、おかしくて、私は家族と仲良くできません。', '実際、彼らは今年素晴らしいクリスマスを過ごしました。', 'クリスマスって、本当にいいですね。', 'さあクリスマスの準備ですね']
# ['が、おかしくて、私は家族と仲良くできない。', '実際、彼らは今年素晴らしいクリスマスを過ごした。', 'クリスマスって、本当にいいね。', 'さあクリスマスの準備だね']
# ['が、おかしくて、私は家族と仲良く[F]できません[/F]。', '実際、彼らは今年素晴らしいクリスマスを[F]過ごしました[/F]。', 'クリスマスって、本当に[F]いいです[/F]ね。', 'さあクリスマスの準備[F]です[/F]ね']
# ['が、おかしくて、私は家族と仲良く[F]できない[/F]。', '実際、彼らは今年素晴らしいクリスマスを[F]過ごした[/F]。', 'クリスマスって、本当に[F]いい[/F]ね。', 'さあクリスマスの準備[F]だ[/F]ね']
#
# Different number of sentences found in the following example:
# ["but I think they are, I just think that sooner or later it's gonna crumble."]
# ['しかし、彼らはそうだと思います。', 'ただ、遅かれ早かれ崩れていくと思います。']
# ['しかし、彼らはそうだと思う。', 'ただ、遅かれ早かれ崩れていくと思う。']
# ['しかし、彼らはそうだと[F]思います[/F]。', 'ただ、遅かれ早かれ崩れていくと[F]思います[/F]。']
# ['しかし、彼らはそうだと[F]思う[/F]。', 'ただ、遅かれ早かれ崩れていくと[F]思う[/F]。']
#
# Different number of sentences found in the following example:
# ['Oh yeah makes sense .', "crazy, oh my goodness well I don't know .", 'I do wanna go but I, where do you stay?', 'Because what she told me']
# ['なるほど、そうですか。', '私は行きたいのですが、あなたはどこに滞在しますか？', '彼女が言ったことは']
# ['なるほど、そうか。', '私は行きたいのだが、あなたはどこに滞在しますか？', '彼女が言ったことは']
# ['なるほど、そう[F]です[/F]か。', '私は[F]行きたいのです[/F]が、あなたはどこに[F]滞在します[/F]か？', '彼女が[F]言った[/F]ことは']
# ['なるほど、そうか。', '私は[F]行きたいのだ[/F]が、あなたはどこに[F]滞在します[/F]か？', '彼女が[F]言った[/F]ことは']
#
# Different number of sentences found in the following example:
# ["I hope so, so I could put them in sports, but I can't wait, but I've always been telling my kids a lot"]
# ['そう願っています。', '私は子供たちにスポーツをさせたいと思っています。', '待ちきれません。', '子供たちには、いつもたくさん話をしています']
# ['そう願っている。', '私は子供たちにスポーツをさせたいと思っている。', '待ちきれない。', '子供たちには、いつもたくさん話をしている']
# ['そう[F]願っています[/F]。', '私は子供たちにスポーツをさせたいと[F]思っています[/F]。', '[F]待ちきれません[/F]。', '子供たちには、いつもたくさん[F]話をしています[/F]']
# ['そう[F]願っている[/F]。', '私は子供たちにスポーツをさせたいと[F]思っている[/F]。', '[F]待ちきれない[/F]。', '子供たちには、いつもたくさん[F]話をしている[/F]']
#
# Different number of sentences found in the following example:
# ['raspberry or peach are kind of my favorites.', "don't really like passion for coconut tastes too much like a pina colada.", 'So in general, I prefer the raspberry and strawberry or the peach']
# ['パッション・フォー・ココナッツはピニャコラーダのような味であまり好きではありません。', 'だから一般的には、ラズベリーとストロベリー、またはピーチが好きです。']
# ['パッション・フォー・ココナッツはピニャコラーダのような味であまり好きではない。', 'だから一般的には、ラズベリーとストロベリー、またはピーチが好きだ。']
# ['パッション・フォー・ココナッツはピニャコラーダのような味であまり好きでは[F]ありません[/F]。', 'だから一般的には、ラズベリーとストロベリー、またはピーチが[F]好きです[/F]。']
# ['パッション・フォー・ココナッツはピニャコラーダのような味であまり好きでは[F]ない[/F]。', 'だから一般的には、ラズベリーとストロベリー、またはピーチが[F]好きだ[/F]。']
#
# Different number of sentences found in the following example:
# ['Yeah, you can get that anywhere.', 'walmart, CVS personally, myself, I used to enjoy walking down electronics stores.']
# ['ええ、あなたはそれをどこでも手に入れることができます。', 'ウォルマート、CVS。', '個人的には、昔は家電量販店を歩くのが楽しかったですね。']
# ['ええ、あなたはそれをどこでも手に入れることができる。', 'ウォルマート、CVS。', '個人的には、昔は家電量販店を歩くのが楽しかった。']
# ['ええ、あなたはそれをどこでも手に入れることが[F]できます[/F]。', 'ウォルマート、CVS。', '個人的には、昔は家電量販店を歩くのが楽しかった[F]です[/F]ね。']
# ['ええ、あなたはそれをどこでも手に入れることが[F]できる[/F]。', 'ウォルマート、CVS。', '個人的には、昔は家電量販店を歩くのが楽しかった。']
#
# Different number of sentences found in the following example:
# ['people were checking for me, so I was like, okay whatever.', 'So she was like, oh!', 'Come meet me and my friends and we are gonna have some wine,']
# ['みんなが私のことをチェックしてくれていたので、何でもいいと思っていました。', 'すると彼女は、「ああ！私と私の友達に会って、ワインを飲みましょう」と言ってくれました。']
# ['みんなが私のことをチェックしてくれていたので、何でもいいと思っていた。', 'すると彼女は、「ああ！私と私の友達に会って、ワインを飲みましょう」と言ってくれた。']
# ['みんなが私のことを[F]チェックしてくれていた[/F]ので、何でもいいと[F]思っていました[/F]。', 'すると彼女は、「ああ！私と私の友達に会って、ワインを飲みましょう」と[F]言ってくれました[/F]。']
# ['みんなが私のことを[F]チェックしてくれていた[/F]ので、何でもいいと[F]思っていた[/F]。', 'すると彼女は、「ああ！私と私の友達に会って、ワインを飲みましょう」と[F]言ってくれた[/F]。']
#
# Different number of sentences found in the following example:
# ['You know Frank how is it gonna be.', 'the insurance company was going to give me (ten thousand dollars) for my hit and run case with Frank']
# ['フランクの起こしたひき逃げ事件で、保険会社が私に（1万ドル）くれることになっていたのですが、どうなるでしょうか？']
# ['フランクの起こしたひき逃げ事件で、保険会社が私に（1万ドル）くれることになっていたのだが、どうなるだろうか？']
# ['フランクの起こしたひき逃げ事件で、保険会社が私に（1万ドル）くれることに[F]なっていたのです[/F]が、どう[F]なるでしょう[/F]か？']
# ['フランクの起こしたひき逃げ事件で、保険会社が私に（1万ドル）くれることに[F]なっていたのだ[/F]が、どう[F]なるだろう[/F]か？']
#
# Different number of sentences found in the following example:
# ['you know, over a year, I had become very attached to this person.', "And, it wasn't healthy for me anymore, because I wanted more and he, he was never gonna want more."]
# ['1年以上の間に、私はその人にさらに執着するようになりました。', 'そして、それは私にとってもう健康的ではありませんでした。', 'というのも、私はもっと彼を求めるようになりましたが、彼がさらに私を求めることはなかったからです。']
# ['1年以上の間に、私はその人にさらに執着するようになった。', 'そして、それは私にとってもう健康的ではなかった。', 'というのも、私はもっと彼を求めるようになったが、彼がさらに私を求めることはなかったからだ。']
# ['1年以上の間に、私はその人にさらに執着するように[F]なりました[/F]。', 'そして、それは私にとってもう健康的では[F]ありませんでした[/F]。', 'というのも、私はもっと彼を求める[F]ようになりました[/F]が、彼がさらに私を求めることはなかったから[F]です[/F]。']
# ['1年以上の間に、私はその人にさらに執着するように[F]なった[/F]。', 'そして、それは私にとってもう健康的では[F]なかった[/F]。', 'というのも、私はもっと彼を求める[F]ようになった[/F]が、彼がさらに私を求めることはなかったから[F]だ[/F]。']
#
# Different number of sentences found in the following example:
# ['and was laughing and she was like I just reported this girl Instagram to the principal and everyone was like laughing about it and I called my dad and I was like please come pick me up']
# ['彼女はインスタグラムについて校長に通報されたようで、みんなが笑っていました。', '私は父に電話をして、「どうか私を迎えに来て」と言いました。']
# ['彼女はインスタグラムについて校長に通報されたようで、みんなが笑っていた。', '私は父に電話をして、「どうか私を迎えに来て」と言った。']
# ['彼女はインスタグラムについて校長に通報されたようで、みんなが[F]笑っていました[/F]。', '私は父に電話をして、「どうか私を迎えに来て」と[F]言いました[/F]。']
# ['彼女はインスタグラムについて校長に通報されたようで、みんなが[F]笑っていた[/F]。', '私は父に電話をして、「どうか私を迎えに来て」と[F]言った[/F]。']
#
# Different number of sentences found in the following example:
# ["My in-laws suck, my wife's mother could be a low funny she'd be funny with stuff, and she's just weird"]
# ['私の義理の両親は最悪です、私の妻の母親は、彼女は面白いかもしれません。', '彼女の資質は面白いです、そして、彼女はただ変わり者です。']
# ['私の義理の両親は最悪だ、私の妻の母親は、彼女は面白いかもしれない。', '彼女の資質は面白い、そして、彼女はただ変わり者だ。']
# ['私の義理の両親は[F]最悪です[/F]、私の妻の母親は、彼女は面白いかも[F]しれません[/F]。', '彼女の資質は[F]面白いです[/F]、そして、彼女はただ変わり者[F]です[/F]。']
# ['私の義理の両親は[F]最悪だ[/F]、私の妻の母親は、彼女は面白いかも[F]しれない[/F]。', '彼女の資質は[F]面白い[/F]、そして、彼女はただ変わり者[F]だ[/F]。']
#
# Different number of sentences found in the following example:
# ['Not really, my parents tried to get me, but I was too nervous because of the French']
# ['そうではありません。', '両親は私を捕まえようとしましたが、私はフランス人のせいで緊張していました。']
# ['そうではないわ。', '両親は私を捕まえようとしたけど、私はフランス人のせいで緊張していたの。']
# ['そうでは[F]ありません[/F]。', '両親は私を捕まえようと[F]しましたが[/F]、私はフランス人のせいで[F]緊張していました[/F]。']
# ['そうでは[F]ない[/F]わ。', '両親は私を捕まえようと[F]した[/F]けど、私はフランス人のせいで[F]緊張していた[/F]の。']
#
# Different number of sentences found in the following example:
# ["That's good because years ago they would, I, because there's some old family stories of mine and like nobody's too sure."]
# ['それはいいことです。', '何年も前には、彼らはそうしていたでしょうし、私も、私の家族の古い話を聞いて、誰も確信を持てなかったからです。']
# ['それはいいことだ。', '何年も前には、彼らはそうしていただろうし、私も、私の家族の古い話を聞いて、誰も確信を持てなかったからだ。']
# ['それはいいこと[F]です[/F]。', '何年も前には、彼らは[F]そうしていたでしょう[/F]し、私も、私の家族の古い話を[F]聞いて[/F]、誰も確信を[F]持てなかったからです[/F]。']
# ['それはいいこと[F]だ[/F]。', '何年も前には、彼らは[F]そうしていただろう[/F]し、私も、私の家族の古い話を[F]聞いて[/F]、誰も確信を[F]持てなかったからだ[/F]。']
#
# Different number of sentences found in the following example:
# ['I wanted a friend of mine, a friend of my dad, is a lawyer and he is a friend of his']
# ['私は自分の友人が欲しかったです。', '父の友人は弁護士ですが、やはり父の友人でした']
# ['私は自分の友人が欲しかった。', '父の友人は弁護士だが、やはり父の友人だった']
# ['私は自分の友人が欲しかった[F]です[/F]。', '父の友人は弁護士[F]です[/F]が、やはり父の友人[F]でした[/F]']
# ['私は自分の友人が欲しかった。', '父の友人は弁護士[F]だ[/F]が、やはり父の友人[F]だった[/F]']
#
# Different number of sentences found in the following example:
# ["I was like, yo, mom this lady ain't cool.", 'Nah!', 'If you know what I mean.', 'How could she be sitting on my couch drinking our water and tell me what to do while she is']
# ['私は、お母さん、この女性は駄目だよと言いました。', 'なんて言ったら良いか。', '私のソファに座って、私たちの水を飲みながら、彼女がいる間、私が何をすべきか言うなんて。']
# ['私は、お母さん、この女性は駄目だよと言った。', 'なんて言ったら良いか。', '私のソファに座って、私たちの水を飲みながら、彼女がいる間、私が何をすべきか言うなんて。']
# ['私は、お母さん、この女性は駄目だよと[F]言いました[/F]。', 'なんて言ったら良いか。', '私のソファに座って、私たちの水を飲みながら、彼女がいる間、私が何をすべきか言うなんて。']
# ['私は、お母さん、この女性は駄目だよと[F]言った[/F]。', 'なんて言ったら良いか。', '私のソファに座って、私たちの水を飲みながら、彼女がいる間、私が何をすべきか言うなんて。']
#
# Different number of sentences found in the following example:
# ['quote, unquote like (Bond) girls that they have, it was that great sixties costuming and stuff but I never really thought it was very funny either but confused me was different']
# ['引用、引用終わり、彼らがかかえている（ボンド）ガールでわかるような、偉大な60年代のコスチュームなど。', 'しかし私はあまり面白いと思ったことはありませんでしたが、私を混乱させたのは別のものでした。']
# ['引用、引用終わり、彼らがかかえている（ボンド）ガールでわかるような、偉大な60年代のコスチュームなど。', 'しかし私はあまり面白いと思ったことはなかったが、私を混乱させたのは別のものだった。']
# ['引用、引用終わり、彼らがかかえている（ボンド）ガールでわかるような、偉大な60年代のコスチュームなど。', 'しかし私はあまり面白いと思ったことは[F]ありませんでした[/F]が、私を混乱させたのは別のもの[F]でした[/F]。']
# ['引用、引用終わり、彼らがかかえている（ボンド）ガールでわかるような、偉大な60年代のコスチュームなど。', 'しかし私はあまり面白いと思ったことは[F]なかった[/F]が、私を混乱させたのは別のもの[F]だった[/F]。']
#
# Different number of sentences found in the following example:
# ['you know what I am saying they always help you out, whatever you need, your family got your back']
# ['分かりますよね、彼らはいつでも助けてくれます。', '何が必要だとしても、ご家族が付いています']
# ['分かるでしょ、彼らはいつでも助けてくれる。', '何が必要だとしても、家族が付いている']
# ['[F]分かります[/F]よね、彼らはいつでも[F]助けてくれます[/F]。', '何が必要だとしても、ご家族が[F]付いています[/F]']
# ['[F]分かる[/F]でしょ、彼らはいつでも[F]助けてくれる[/F]。', '何が必要だとしても、家族が[F]付いている[/F]']
#
# Different number of sentences found in the following example:
# ["Also your financial so it's everything you have to take into consideration.", "But I can't believe that if it costs that much to eat in the future."]
# ['それとあなたの経済的なことです。', 'つまり、全部を考慮に入れないといけません。', 'でも、将来食べ物にそんなに費用がかかるなんて信じられません。']
# ['それとあなたの経済的なこと。', 'つまり、全部を考慮に入れないといけない。', 'でも、将来食べ物にそんなに費用がかかるなんて信じられない。']
# ['それとあなたの経済的なこと[F]です[/F]。', 'つまり、全部を考慮に入れないと[F]いけません[/F]。', 'でも、将来食べ物にそんなに費用がかかるなんて[F]信じられません[/F]。']
# ['それとあなたの経済的なこと。', 'つまり、全部を考慮に入れないと[F]いけない[/F]。', 'でも、将来食べ物にそんなに費用がかかるなんて[F]信じられない[/F]。']
#
# Different number of sentences found in the following example:
# ['Do you have any favourite memories of your friends or like have you ever like a ride on them or is there a story that I definitely wanna know?']
# ['友達との一番好きな思い出はありますか？', 'それか、たとえば一緒に乗り物に乗ったこととか、私が聞きたいような話はありますか？']
# ['友達との一番好きな思い出はある？', 'それか、たとえば一緒に乗り物に乗ったこととか、私が聞きたいような話はある？']
# ['友達との一番[F]好きな[/F]思い出は[F]あります[/F]か？', 'それか、たとえば一緒に乗り物に乗ったこととか、私が[F]聞きたい[/F]ような話は[F]あります[/F]か？']
# ['友達との一番[F]好きな[/F]思い出は[F]ある[/F]？', 'それか、たとえば一緒に乗り物に乗ったこととか、私が[F]聞きたい[/F]ような話は[F]ある[/F]？']
#
# Different number of sentences found in the following example:
# ["Yeah my parents were talking about going there and traveling there and stuff and all of that, but let's talk about the in-laws, how did you get along with your wife?"]
# ['はい、私の両親がそこに行くだのあそこに旅行するだのと話していました。', 'でも、義理の家族について話しましょう。', '奥さんとはどうやってうまくやってきましたか？']
# ['うん、私の両親がそこに行くだのあそこに旅行するだのと話していたよ。', 'でも、義理の家族について話そう。', '奥さんとはどうやってうまくやってきた？']
# ['はい、私の両親がそこに行くだのあそこに旅行するだのと[F]話していました[/F]。', 'でも、義理の家族について[F]話しましょう[/F]。', '奥さんとはどうやってうまく[F]やってきました[/F]か？']
# ['うん、私の両親がそこに行くだのあそこに旅行するだのと[F]話していた[/F]よ。', 'でも、義理の家族について[F]話そう[/F]。', '奥さんとはどうやってうまく[F]やってきた[/F]？']
#
# Different number of sentences found in the following example:
# ["you close the account and you can do that online, you can give the cause and then closing my account tomorrow and my my sister's"]
# ['アカウントのクローズはオンラインで行うことができます。', '原因を伝え、明日私のアカウントと私の妹のアカウントをクローズすることを伝えます。']
# ['アカウントのクローズはオンラインで行うことができる。', '原因を伝え、明日私のアカウントと私の妹のアカウントをクローズすることを伝える。']
# ['アカウントのクローズはオンラインで行うことが[F]できます[/F]。', '原因を伝え、明日私のアカウントと私の妹のアカウントをクローズすることを[F]伝えます[/F]。']
# ['アカウントのクローズはオンラインで行うことが[F]できる[/F]。', '原因を伝え、明日私のアカウントと私の妹のアカウントをクローズすることを[F]伝える[/F]。']
#
# Different number of sentences found in the following example:
# ['Alright, the payment went through.', 'Thanks for choosing AMC, enjoy your movie.', 'You have a good time.']
# ['では、支払いは完了しました。', 'AMCを選んでくれてありがとう。', '映画を楽しんでください。', '良い時間を過ごしてください。']
# ['では、支払いは完了した。', 'AMCを選んでくれてありがとう。', '映画を楽しんで。', '良い時間を過ごして。']
# ['では、支払いは[F]完了しました[/F]。', 'AMCを[F]選んでくれて[/F]ありがとう。', '映画を[F]楽しんでください[/F]。', '良い時間を[F]過ごしてください[/F]。']
# ['では、支払いは[F]完了した[/F]。', 'AMCを[F]選んでくれて[/F]ありがとう。', '映画を[F]楽しんで[/F]。', '良い時間を[F]過ごして[/F]。']
#
# Different number of sentences found in the following example:
# ['Okay no your flight is not cancelled until you have received a confirmation from us, you need to contact us as early as possible, different airlines have different rules from how late.']
# ['はい、いいえ、弊社からの確認が手元に届くまでフライトはキャンセルされません。', 'できるだけ早く弊社に連絡していただく必要があります。', '航空会社によっては確認が遅くなります。']
# ['はい、いいえ、弊社からの確認が手元に届くまでフライトはキャンセルされない。', 'できるだけ早く弊社に連絡していただく必要がある。', '航空会社によっては確認が遅くなる。']
# ['はい、いいえ、弊社からの確認が[F]手元に届く[/F]までフライトは[F]キャンセルされません[/F]。', 'できるだけ早く弊社に[F]連絡していただく[/F]必要が[F]あります[/F]。', '航空会社によっては確認が遅く[F]なります[/F]。']
# ['はい、いいえ、弊社からの確認が[F]手元に届く[/F]までフライトは[F]キャンセルされない[/F]。', 'できるだけ早く弊社に[F]連絡していただく[/F]必要が[F]ある[/F]。', '航空会社によっては確認が遅く[F]なる[/F]。']
#
# Different number of sentences found in the following example:
# ["Then you can put in your pocket and use when you want to flip it out, it's a full screen."]
# ['それから、ポケットに入れて、逆にしたいときも使用できます。', '全画面表示です。']
# ['それから、ポケットに入れて、逆にしたいときも使用できるよ。', '全画面表示だ。']
# ['それから、ポケットに入れて、逆にしたいときも[F]使用できます[/F]。', '全画面表示[F]です[/F]。']
# ['それから、ポケットに入れて、逆にしたいときも[F]使用できる[/F]よ。', '全画面表示[F]だ[/F]。']
#
# Different number of sentences found in the following example:
# ['You know what I mean?', "that instant gratification that relies on you know, this is a game, it's in my control, sort of making that all work.", 'What what are your thoughts on that?']
# ['つまり、何て言ったらいいか、「これはゲームだから、自分でコントロールできる」と信じ切って、即効性のある満足感に浸ることで、すべてが成り立っているということです。', 'それについてどう思いますか？']
# ['つまり、何て言ったらいいか、「これはゲームだから、自分でコントロールできる」と信じ切って、即効性のある満足感に浸ることで、すべてが成り立っているということだ。', 'それについてどう思う？']
# ['つまり、何て言ったらいいか、「これはゲームだから、自分でコントロールできる」と信じ切って、即効性のある満足感に浸ることで、すべてが成り立っているということ[F]です[/F]。', 'それについてどう[F]思います[/F]か？']
# ['つまり、何て言ったらいいか、「これはゲームだから、自分でコントロールできる」と信じ切って、即効性のある満足感に浸ることで、すべてが成り立っているということ[F]だ[/F]。', 'それについてどう[F]思う[/F]？']
#
# Different number of sentences found in the following example:
# ["it doesn't stop, it just grows, everything grows, you know what I am saying"]
# ['止まりません、ただ成長し続けます。', 'なんでも成長します、分かりますよね']
# ['止まらない、ただ成長し続ける。', 'なんでも成長する、分かるでしょ']
# ['[F]止まりません[/F]、ただ[F]成長し続けます[/F]。', 'なんでも[F]成長します[/F]、[F]分かります[/F]よね']
# ['[F]止まらない[/F]、ただ[F]成長し続ける[/F]。', 'なんでも[F]成長する[/F]、[F]分かる[/F]でしょ']
#
# Different number of sentences found in the following example:
# ['Yeah, exactly.', 'Okay now also have a look on my fashion stores where do you shop?']
# ['ええ、その通りです。', 'さて、私のファッション店も見てください。', 'あなたはどこで買い物をしていますか？']
# ['ええ、その通りです。', 'さて、私のファッション店も見て。', 'あなたはどこで買い物をしている？']
# ['ええ、その通りです。', 'さて、私のファッション店も[F]見てください[/F]。', 'あなたはどこで買い物を[F]しています[/F]か？']
# ['ええ、その通りです。', 'さて、私のファッション店も[F]見て[/F]。', 'あなたはどこで買い物を[F]している[/F]？']
#
# Different number of sentences found in the following example:
# ['being a student in school, you know what I mean?', "It's definitely helpful.", "It's convenient I mean your full-time student does not really have a car."]
# ['学生であることは、何を意味するかわかりますか？', 'それは間違いなく役に立ちます。', '便利です。', 'フルタイムの学生は実際には車など持っていないということです。']
# ['学生であることは、何を意味するかわかる？', 'それは間違いなく役に立つよ。', '便利だ。', 'フルタイムの学生は実際には車など持っていないということだ。']
# ['学生であることは、何を意味するか[F]わかります[/F]か？', 'それは間違いなく[F]役に立ちます[/F]。', '[F]便利です[/F]。', 'フルタイムの学生は実際には車など持っていないということ[F]です[/F]。']
# ['学生であることは、何を意味するか[F]わかる[/F]？', 'それは間違いなく[F]役に立つ[/F]よ。', '[F]便利だ[/F]。', 'フルタイムの学生は実際には車など持っていないということ[F]だ[/F]。']
#
# Different number of sentences found in the following example:
# ["That's why they are all cool, they are a little crazy, you know what I am saying?"]
# ['ですから彼らはみんなすごいです、ちょっとぶっ飛んでいます。', '言っていること分かりますかね？']
# ['だから彼らはみんなすごい、ちょっとぶっ飛んでる。', '言っていること分かるかな？']
# ['ですから彼らはみんな[F]すごいです[/F]、ちょっと[F]ぶっ飛んでいます[/F]。', '[F]言っている[/F]こと[F]分かります[/F]かね？']
# ['だから彼らはみんな[F]すごい[/F]、ちょっと[F]ぶっ飛んでる[/F]。', '[F]言っている[/F]こと[F]分かる[/F]かな？']
#
# Different number of sentences found in the following example:
# ['I actually read a book or, imagine, I read a book on your love language and learning it, your attachment styles and stuff with your partner']
# ['私は実際に本を読みました、想像してみてください。', '本であなたの愛の言葉を読み、その言葉やあなたのパートナーに対する愛情表現などを覚えました。']
# ['私は実際に本を読んだわ、想像してみて。', '本であなたの愛の言葉を読み、その言葉やあなたのパートナーに対する愛情表現などを覚えた。']
# ['私は実際に本を[F]読みました[/F]、[F]想像してみてください[/F]。', '本であなたの愛の言葉を読み、その言葉やあなたのパートナーに対する愛情表現などを[F]覚えました[/F]。']
# ['私は実際に本を[F]読んだ[/F]わ、[F]想像してみて[/F]。', '本であなたの愛の言葉を読み、その言葉やあなたのパートナーに対する愛情表現などを[F]覚えた[/F]。']
#
# Different number of sentences found in the following example:
# ['between meters and just everything, and even just worrying about your car getting clipped.', 'Parking is a real pain in the butt.', 'How do you find parking in Astoria?']
# ['メーターやいろんなもの、車がぶつかったりすることを心配するだけでも、駐車場は本当に面倒です。', 'アストリアの駐車場はどうやって探しますか？']
# ['メーターやいろんなもの、車がぶつかったりすることを心配するだけでも、駐車場は本当に面倒だ。', 'アストリアの駐車場はどうやって探すの？']
# ['メーターやいろんなもの、車がぶつかったりすることを心配するだけでも、駐車場は本当に[F]面倒です[/F]。', 'アストリアの駐車場はどうやって[F]探します[/F]か？']
# ['メーターやいろんなもの、車がぶつかったりすることを心配するだけでも、駐車場は本当に[F]面倒だ[/F]。', 'アストリアの駐車場はどうやって[F]探す[/F]の？']
#
# Different number of sentences found in the following example:
# ['Hey Summer how was your day today?']
# ['やあ、サマー。', '今日はどうでした？']
# ['やあ、サマー。', '今日はどうだった？']
# ['やあ、サマー。', '今日はどう[F]でした[/F]？']
# ['やあ、サマー。', '今日はどう[F]だった[/F]？']
#
# Different number of sentences found in the following example:
# ['I just see how I can be without a degree.', "there are so many jobs you can't enable yourself into new jobs anymore."]
# ['学位がないと自分がどうなるかが私にはわかるよ。', '職はたくさんある。', 'もう新しい仕事には就けないでしょう。']
# ['学位がないと自分がどうなるかが私にはわかるよ。', '職はたくさんある。', 'もう新しい仕事には就けないだろう。']
# ['学位がないと自分がどうなるかが私には[F]わかる[/F]よ。', '職はたくさんある。', 'もう新しい仕事には就けない[F]でしょう[/F]。']
# ['学位がないと自分がどうなるかが私には[F]わかる[/F]よ。', '職はたくさんある。', 'もう新しい仕事には就けない[F]だろう[/F]。']
#
# Different number of sentences found in the following example:
# ["That's true.", "but yeah, that's another thing when friends don't budget correctly and then they're out there and your like I'm not giving you money."]
# ['それは本当ですしかし、ええ、それは友人が正しく予算を組んでおらず、予算オーバーになって、資金提供はしないとあなたが言われたようなときは話は別です。']
# ['それは本当だよ。', 'しかし、ええ、それは友人が正しく予算を組んでおらず、予算オーバーになって、資金提供はしないとあなたが言われたようなときは話は別だ。']
# ['それは本当[F]です[/F]しかし、ええ、それは友人が正しく予算を組んでおらず、予算オーバーになって、資金提供はしないとあなたが言われたようなときは話は[F]別です[/F]。']
# ['それは本当[F]だ[/F]よ。', 'しかし、ええ、それは友人が正しく予算を組んでおらず、予算オーバーになって、資金提供はしないとあなたが言われたようなときは話は[F]別だ[/F]。']
#
# Different number of sentences found in the following example:
# ["how they can benefit society, just being who they are, because the more they be who they are, it's just more beneficial you know?"]
# ['彼らが自分らしくありながら、どう社会に貢献できるか。', 'なぜなら、彼らがありのままでいればいるほど、メリットが大きくなるでしょう？']
# ['彼らが自分らしくありながら、どう社会に貢献できるか。', 'だって、彼らがありのままでいればいるほど、メリットが大きくなるだろう？']
# ['彼らが自分らしくありながら、どう社会に貢献できるか。', 'なぜなら、彼らがありのままでいればいるほど、メリットが[F]大きくなるでしょう[/F]？']
# ['彼らが自分らしくありながら、どう社会に貢献できるか。', 'だって、彼らがありのままでいればいるほど、メリットが[F]大きくなるだろう[/F]？']
#
# Different number of sentences found in the following example:
# ['Have you ever player Hockey?', "I'm not good on skates so it never tempted me, I'd be dangerous with a hockey stick in my hand."]
# ['ホッケーの選手でしたか？', '私はスケートが苦手なので、したいと思ったことはありません。', '私がホッケースティックを手にするとで危険す。']
# ['ホッケーの選手だった？', '私はスケートが苦手なので、したいと思ったことはない。', '私がホッケースティックを手にすると危険だ。']
# ['ホッケーの選手[F]でした[/F]か？', '私はスケートが苦手なので、したいと思ったことは[F]ありません[/F]。', '私がホッケースティックを手にすると[F]で危険す[/F]。']
# ['ホッケーの選手[F]だった[/F]？', '私はスケートが苦手なので、したいと思ったことは[F]ない[/F]。', '私がホッケースティックを手にすると[F]危険だ[/F]。']
#
# Different number of sentences found in the following example:
# ["Wow that is crazy that's a lot of calories to burn in a day!", "I'm just glad that Amazon has an exclusive contract with USPS to deliver on Sundays, that makes me happy"]
# ['わぁ、それはおかしいです。', '一日に消費するカロリーとしては多すぎます！', 'アマゾンがUSPSと日曜日に配達する独占契約を結んでいることを嬉しく思います。', '安心です']
# ['わぁ、それはおかしいよ。', '一日に消費するカロリーとしては多すぎだ！', 'アマゾンがUSPSと日曜日に配達する独占契約を結んでいることは嬉しいよ。', '安心だ']
# ['わぁ、それは[F]おかしいです[/F]。', '一日に消費するカロリーとしては[F]多すぎます[/F]！', 'アマゾンがUSPSと日曜日に配達する独占契約を結んでいることを[F]嬉しく思います[/F]。', '[F]安心です[/F]']
# ['わぁ、それは[F]おかしい[/F]よ。', '一日に消費するカロリーとしては[F]多すぎだ[/F]！', 'アマゾンがUSPSと日曜日に配達する独占契約を結んでいることは[F]嬉しい[/F]よ。', '[F]安心だ[/F]']
#
# Different number of sentences found in the following example:
# ['Yes, so delightful and treasured.', 'Mine will mimic things that make me run looking for alarms sometimes.lol']
# ['はい、とても楽しくて貴重です。', '私のは時々私にアラームの場所を探して走らせ、からかいます。', '笑']
# ['はい、とても楽しくて貴重だ。', '私のは時々私にアラームの場所を探して走らせ、からかうんだ。', '笑']
# ['はい、とても[F]楽しくて貴重です[/F]。', '私のは時々私にアラームの場所を探して走らせ、[F]からかいます[/F]。', '笑']
# ['はい、とても[F]楽しくて貴重だ[/F]。', '私のは時々私にアラームの場所を探して走らせ、[F]からかうんだ[/F]。', '笑']
#
# Different number of sentences found in the following example:
# ['Nice I enjoy watching the world series, my favorite team is the Red Sox, they won it this year!']
# ['ワールドシリーズを見て楽しんでいます。', '私のお気に入りのチームはレッドソックスです。', '今年は優勝しました。']
# ['ワールドシリーズを見て楽しんでいるよ。', '私のお気に入りのチームはレッドソックスだ。', '今年は優勝したよ。']
# ['ワールドシリーズを見て[F]楽しんでいます[/F]。', '私のお気に入りのチームはレッドソックス[F]です[/F]。', '今年は[F]優勝しました[/F]。']
# ['ワールドシリーズを見て[F]楽しんでいる[/F]よ。', '私のお気に入りのチームはレッドソックス[F]だ[/F]。', '今年は[F]優勝した[/F]よ。']
#
# Different number of sentences found in the following example:
# ['That is amazing, 2430 games every year that is just too many numbers for me']
# ['それは驚くべきことです。', '毎年2430のゲームが現れるなど、私には数が多すぎます。']
# ['それは驚くべきことだよ。', '毎年2430のゲームが現れるなど、私には数が多すぎる。']
# ['それは驚くべきこと[F]です[/F]。', '毎年2430のゲームが現れるなど、私には数が[F]多すぎます[/F]。']
# ['それは驚くべきこと[F]だ[/F]よ。', '毎年2430のゲームが現れるなど、私には数が[F]多すぎる[/F]。']
#
# Different number of sentences found in the following example:
# ['Aha!', 'I was just racking my brain about EM in that movie!', 'And now I need to figure out who his wife is!!', '!']
# ['ああ、あの映画のEM エンバーミングについて頭を悩ませていたところです!', 'そして、今度は彼の奥さんが誰なのかを突き止めなければなりません!!!']
# ['ああ、あの映画のEM エンバーミングについて頭を悩ませていたところだ!', 'そして、今度は彼の奥さんが誰なのかを突き止めなければならない!!!']
# ['ああ、あの映画のEM エンバーミングについて頭を悩ませていたところ[F]です[/F]!', 'そして、今度は彼の奥さんが誰なのかを[F]突き止めなければなりません[/F]!!!']
# ['ああ、あの映画のEM エンバーミングについて頭を悩ませていたところ[F]だ[/F]!', 'そして、今度は彼の奥さんが誰なのかを[F]突き止めなければならない[/F]!!!']
#
# Different number of sentences found in the following example:
# ['Yeah, I play a little bit when I was a child but it was not for me, my fingers are short lol.']
# ['ええ、子供の頃は少し弾いていましたが、私には向いていませんでした。', '指が短いのです笑。']
# ['うん 、子供の頃は少し弾いていたが、私には向いていなかったね。', '指が短いのだ笑。']
# ['ええ、子供の頃は少し[F]弾いていました[/F]が、私には向いて[F]いませんでした[/F]。', '指が[F]短いのです[/F]笑。']
# ['うん 、子供の頃は少し[F]弾いていた[/F]が、私には向いて[F]いなかった[/F]ね。', '指が[F]短いのだ[/F]笑。']
#
# Different number of sentences found in the following example:
# ['I will have to, yes, his name is rocky, he is my favorite pet of all time, what is your dogs name?']
# ['はい、彼の名前はロッキーです。', '彼はずっと私のお気に入りのペットです。', 'あなたの犬の名前は何ですか？']
# ['はい、彼の名前はロッキーだ。', '彼はずっと私のお気に入りのペットだ。', 'あなたの犬の名前は何？']
# ['はい、彼の名前はロッキー[F]です[/F]。', '彼はずっと私のお気に入りのペット[F]です[/F]。', 'あなたの犬の名前は何[F]です[/F]か？']
# ['はい、彼の名前はロッキー[F]だ[/F]。', '彼はずっと私のお気に入りのペット[F]だ[/F]。', 'あなたの犬の名前は何？']
#
# Different number of sentences found in the following example:
# ['ah yup, all my friends have iphones, but my brother and I are the holdouts with android, theyre just way better with more customizations imo']
# ['ああ、うん、私の友達はみんなiPhoneを持っているけど、依然兄と私はアンドロイドです。', 'カスタマイズできればずっと良くなります。', '私の考えでは。']
# ['ああ、うん、私の友達はみんなiPhoneを持っているけど、依然兄と私はアンドロイドだ。', 'カスタマイズできればずっと良くなるよ。', '私の考えでは。']
# ['ああ、うん、私の友達はみんなiPhoneを持っているけど、依然兄と私はアンドロイド[F]です[/F]。', 'カスタマイズできればずっと[F]良くなります[/F]。', '私の考えでは。']
# ['ああ、うん、私の友達はみんなiPhoneを持っているけど、依然兄と私はアンドロイド[F]だ[/F]。', 'カスタマイズできればずっと[F]良くなる[/F]よ。', '私の考えでは。']
#
# Different number of sentences found in the following example:
# ["Okay you've got me there, who's Eeyore."]
# ['OK、私がお応えします。', 'イーヨーって誰ですか。']
# ['OK、私が応えるよ。', 'イーヨーって誰だ。']
# ['OK、私が[F]お応えします[/F]。', 'イーヨーって誰[F]です[/F]か。']
# ['OK、私が[F]応える[/F]よ。', 'イーヨーって誰[F]だ[/F]。']
#
# Different number of sentences found in the following example:
# ['Absolutely not.', 'News is often depressing, and I could stand without it.', "Now, toss on a piano song, or music....now you've got me.", 'Though I hate classical music.', 'Well, most of it.']
# ['絶対違いますニュースは気が滅入るものばかりで、特になくても生きていけます。', 'さて、ピアノの曲、または他の音楽をリクエストしてください....今、私がお応えします。', 'クラシック音楽は嫌いですが。', 'というか、たいていのクラシック曲はね。']
# ['絶対違うよ。', 'ニュースは気が滅入るものばかりで、特になくても生きていけるよ。', 'さて、ピアノの曲、または他の音楽をリクエストして....今、私が応えるので。', 'クラシック音楽は嫌いだが。', 'というか、たいていのクラシック曲はね。']
# ['絶対[F]違います[/F]ニュースは気が滅入るものばかりで、特になくても[F]生きていけます[/F]。', 'さて、ピアノの曲、または他の音楽を[F]リクエストしてください[/F]....今、私が[F]お応えします[/F]。', 'クラシック音楽は[F]嫌いです[/F]が。', 'というか、たいていのクラシック曲はね。']
# ['絶対[F]違う[/F]よ。', 'ニュースは気が滅入るものばかりで、特になくても[F]生きていける[/F]よ。', 'さて、ピアノの曲、または他の音楽を[F]リクエストして[/F]....今、私が[F]応える[/F]ので。', 'クラシック音楽は[F]嫌いだ[/F]が。', 'というか、たいていのクラシック曲はね。']
#
# Different number of sentences found in the following example:
# ['Yes!', 'my older daughter introduced me to them, they are obsessed with K pop and BTS (a boy band in case u havent heard) their songs are catchy']
# ['はい！', '私の長女が私を彼らに紹介してくれました。', '彼らはKポップとBTS（聞いたことがない場合はボーイバンド）に夢中になっています。', '彼らの曲は人の心を捉えます。']
# ['はい！', '私の長女が私を彼らに紹介してくれた。', '彼らはKポップとBTS（聞いたことがない場合はボーイバンド）に夢中になっているよ。', '彼らの曲は人の心を捉える。']
# ['はい！', '私の長女が私を彼らに[F]紹介してくれました[/F]。', '彼らはKポップとBTS（聞いたことがない場合はボーイバンド）に[F]夢中になっています[/F]。', '彼らの曲は人の心を[F]捉えます[/F]。']
# ['はい！', '私の長女が私を彼らに[F]紹介してくれた[/F]。', '彼らはKポップとBTS（聞いたことがない場合はボーイバンド）に[F]夢中になっている[/F]よ。', '彼らの曲は人の心を[F]捉える[/F]。']
#
# Different number of sentences found in the following example:
# ['Hey there my friend do you ever wear shoes.']
# ['ねえ、友達よ。', '靴を履くことはありますか。']
# ['ねえ、友達よ。', '靴を履くことはあるかい。']
# ['ねえ、友達よ。', '靴を[F]履く[/F]ことは[F]あります[/F]か。']
# ['ねえ、友達よ。', '靴を[F]履く[/F]ことは[F]ある[/F]かい。']
#
# Different number of sentences found in the following example:
# ["Noway, I was hugging something at 2 months and it wasn't a racket.", 'That is crazy!', 'It reminds me of a Katy Perry song.']
# ['まさか、私は2ヶ月後、何かを抱きしめていました。', 'そしてそれはラケットではありませんでした。', '信じられないでしょう！', 'ケイティ・ペリーの歌を思い出します。']
# ['まさか、私は2ヶ月後、何かを抱きしめていた。', 'そしてそれはラケットではなかった。', '信じられないだろう！', 'ケイティ・ペリーの歌を思い出すよ。']
# ['まさか、私は2ヶ月後、何かを抱きしめて[F]いました[/F]。', 'そしてそれはラケット[F]ではありませんでした[/F]。', '[F]信じられないでしょう[/F]！', 'ケイティ・ペリーの歌を[F]思い出します[/F]。']
# ['まさか、私は2ヶ月後、何かを抱きしめて[F]いた[/F]。', 'そしてそれはラケット[F]ではなかった[/F]。', '[F]信じられないだろう[/F]！', 'ケイティ・ペリーの歌を[F]思い出す[/F]よ。']
#
# Different number of sentences found in the following example:
# ["No he wasn't.", 'I like Salvador Dali a lot though he was born on my birthday haha.', 'Have you ever seen a"Hidden Mickey"in any of the movies, I guess there\'s a subculture that looks for those in the movies']
# ['いいえ、そうじゃなかったです。', 'サルバドール・ダリは私と誕生日が同じですが、とても好きです、笑。', '映画の中で「隠れミッキー」を見たことがありますか？', '映画の中でミッキーを探すサブカルチャーがあると思います']
# ['いいえ、そうじゃなかった。', 'サルバドール・ダリは私と誕生日が同じだが、とても好きだよ、笑。', '映画の中で「隠れミッキー」を見たことがある？', '映画の中でミッキーを探すサブカルチャーがあると思うよ']
# ['いいえ、そうじゃ[F]なかったです[/F]。', 'サルバドール・ダリは私と誕生日が同じですが、とても[F]好きです[/F]、笑。', '映画の中で「隠れミッキー」を[F]見た[/F]ことが[F]あります[/F]か？', '映画の中でミッキーを探すサブカルチャーがあると[F]思います[/F]']
# ['いいえ、そうじゃ[F]なかった[/F]。', 'サルバドール・ダリは私と誕生日が同じだが、とても[F]好きだ[/F]よ、笑。', '映画の中で「隠れミッキー」を[F]見た[/F]ことが[F]ある[/F]？', '映画の中でミッキーを探すサブカルチャーがあると[F]思う[/F]よ']
#
# Different number of sentences found in the following example:
# ['I agree.', 'Seems odd that Cruise, who has won a Golden Globe Award, never won an Oscar for best actor.', "He's starred in so many films!"]
# ['そのとおりです、ゴールデングローブ賞を受賞したクルーズが、アカデミー主演男優賞を受賞したことがないのは奇妙に思えます。', '彼は非常に多くの映画に出演しています！']
# ['そのとおりだ、ゴールデングローブ賞を受賞したクルーズが、アカデミー主演男優賞を受賞したことがないのは奇妙に思えるよ。', '彼は非常に多くの映画に出演しているんだ！']
# ['[F]そのとおりです[/F]、ゴールデングローブ賞を受賞したクルーズが、アカデミー主演男優賞を受賞したことがないのは奇妙に[F]思えます[/F]。', '彼は非常に多くの映画に[F]出演しています[/F]！']
# ['[F]そのとおりだ[/F]、ゴールデングローブ賞を受賞したクルーズが、アカデミー主演男優賞を受賞したことがないのは奇妙に[F]思える[/F]よ。', '彼は非常に多くの映画に[F]出演している[/F]んだ！']
#
# Different number of sentences found in the following example:
# ['I am allergic to shellfish...maybe that is it.', 'But can you believe this...', 'I named my son Fisher.', 'So there is a little love there!']
# ['私は貝アレルギーです...別に大したことではありません。', 'しかし、あなたは信じることができますか...私は息子をフィッシャーと名付けました。', 'そこには少し愛がこもっています！']
# ['私は貝アレルギーだ...別に大したことではない。', 'しかし、あなたは信じることができるかい...私は息子をフィッシャーと名付けた。', 'そこには少し愛がこもっている！']
# ['私は貝アレルギー[F]です[/F]...別に[F]大したことではありません[/F]。', 'しかし、あなたは[F]信じることができます[/F]か...私は息子をフィッシャーと[F]名付けました[/F]。', 'そこには少し愛が[F]こもっています[/F]！']
# ['私は貝アレルギー[F]だ[/F]...別に[F]大したことではない[/F]。', 'しかし、あなたは[F]信じることができる[/F]かい...私は息子をフィッシャーと[F]名付けた[/F]。', 'そこには少し愛が[F]こもっている[/F]！']
#
# Different number of sentences found in the following example:
# ['Yeah.', "In Kentucky, you can't take office if you've ever participated in a duel.", "Maybe that's what we need more of in politics today -- duels."]
# ['確かにケンタッキー州では、争議に参加したことがあれば公職に就くことはできません。', '争議は現代の政治でもっと必要なことかもしれません。']
# ['確かにケンタッキー州では、争議に参加したことがあれば公職に就くことはできない。', '争議は現代の政治でもっと必要なことかもしれない。']
# ['確かにケンタッキー州では、争議に[F]参加した[/F]ことがあれば公職に就くことは[F]できません[/F]。', '争議は現代の政治でもっと必要なことかも[F]しれません[/F]。']
# ['確かにケンタッキー州では、争議に[F]参加した[/F]ことがあれば公職に就くことは[F]できない[/F]。', '争議は現代の政治でもっと必要なことかも[F]しれない[/F]。']
#
# Different number of sentences found in the following example:
# ['Hey there I love horses.', "Even though I'm allergic to them they are still very fun to ride, what do you think"]
# ['私は馬が大好きです。', 'アレルギーがあっても、馬に乗るのはとても楽しいですよ。', 'あなたはどう思いますか？']
# ['ねえ、私は馬が大好き。', 'アレルギーがあっても、馬に乗るのはとても楽しいよ。', 'あなたはどう思う？']
# ['私は馬が[F]大好きです[/F]。', 'アレルギーがあっても、馬に乗るのはとても[F]楽しいです[/F]よ。', 'あなたはどう[F]思います[/F]か？']
# ['ねえ、私は馬が[F]大好き[/F]。', 'アレルギーがあっても、馬に乗るのはとても[F]楽しい[/F]よ。', 'あなたはどう[F]思う[/F]？']
#
# Different number of sentences found in the following example:
# ['I love watching it, which is your favorite team?']
# ['私はそれを見るのが好きです。', 'あなたのお気に入りのチームはどこですか？']
# ['私はそれを見るのが好きだ。', 'あなたのお気に入りのチームはどこ？']
# ['私はそれを見るのが[F]好きです[/F]。', 'あなたのお気に入りのチームはどこ[F]です[/F]か？']
# ['私はそれを見るのが[F]好きだ[/F]。', 'あなたのお気に入りのチームはどこ？']
#
# Different number of sentences found in the following example:
# ['when the earth was first formed a day was only 5.5 hours long.', 'It was nice chatting with you, have a good night.']
# ['地球が最初に形成された時には、一日は5.5時間だけでした。', '話せて楽しかったですよ。', 'おやすみなさい']
# ['地球が最初に形成された時には、一日は5.5時間だけだった。', '話せて楽しかったよ。', 'おやすみ']
# ['地球が最初に形成された時には、一日は5.5時間だけ[F]でした[/F]。', '[F]話せて[/F][F]楽しかったです[/F]よ。', 'おやすみなさい']
# ['地球が最初に形成された時には、一日は5.5時間だけ[F]だった[/F]。', '[F]話せて[/F][F]楽しかった[/F]よ。', 'おやすみ']
#
# Different number of sentences found in the following example:
# ['What?', 'the drive thru?', 'what exactly was going on at that high school of yours?', 'Respect the drive thru!', 'it was made for the troops!']
# ['え?', 'ドライブスルー?', 'あなたの高校では何が起こっていたんですか?', '軍隊のために作られたので、ドライブスルーには敬意を示さないといけません!']
# ['え?', 'ドライブスルー?', 'あなたの高校では何が起こっていたの?', '軍隊のために作られたから、ドライブスルーには敬意を示さないと!']
# ['え?', 'ドライブスルー?', 'あなたの高校では何が[F]起こっていたんです[/F]か?', '軍隊のために作られたので、ドライブスルーには敬意を示さないと[F]いけません[/F]!']
# ['え?', 'ドライブスルー?', 'あなたの高校では何が[F]起こっていた[/F]の?', '軍隊のために作られたから、ドライブスルーには敬意を示さないと!']
#
# Different number of sentences found in the following example:
# ['Another great idea!', 'You could let your imagination turn fantasy into reality hahaaa.....there is actually a University to go and study fantasy...you could learn all you could imagine lol!', '!']
# ['良いことを思いつきました！', 'あなたの想像力でファンタジーを現実にするんです。', 'あはは……実際に、ファンタジーを学ぶための大学があります。', '想像したことをすべて学べるかもしれませんね笑！']
# ['良いことを思いついた！', 'あなたの想像力でファンタジーを現実にするんだ。', 'あはは……実際に、ファンタジーを学ぶための大学がある。', '想像したことをすべて学べるかもしれないね笑！']
# ['良いことを[F]思いつきました[/F]！', 'あなたの想像力でファンタジーを現実に[F]するんです[/F]。', 'あはは……実際に、ファンタジーを学ぶための大学が[F]あります[/F]。', '想像したことをすべて学べるかも[F]しれません[/F]ね笑！']
# ['良いことを[F]思いついた[/F]！', 'あなたの想像力でファンタジーを現実に[F]するんだ[/F]。', 'あはは……実際に、ファンタジーを学ぶための大学が[F]ある[/F]。', '想像したことをすべて学べるかも[F]しれない[/F]ね笑！']
#
# Different number of sentences found in the following example:
# ['I watch a lot of comedy stuff, How i met your mother, friends, the good place, the santa clarita diet, stuff like that, easy stuff.', 'I do like a lot of drama though, like westworld, the handmaids tale etc.']
# ['「ママと恋に落ちるまで」、「フレンズ」、「グッド・プレイス」、「サンタクラリータ・ダイエット」とか、コメディーはよく見ますよ。', 'ドラマも好きだけど。', '「ウエストワールド」、「ハンドメイズ・テール」とかですね。']
# ['「ママと恋に落ちるまで」、「フレンズ」、「グッド・プレイス」、「サンタクラリータ・ダイエット」とか、コメディーはよく見るよ。', 'ドラマも好きだけど。', '「ウエストワールド」、「ハンドメイズ・テール」とかね。']
# ['「ママと恋に落ちるまで」、「フレンズ」、「グッド・プレイス」、「サンタクラリータ・ダイエット」とか、コメディーはよく[F]見ます[/F]よ。', 'ドラマも好きだけど。', '「ウエストワールド」、「ハンドメイズ・テール」とか[F]です[/F]ね。']
# ['「ママと恋に落ちるまで」、「フレンズ」、「グッド・プレイス」、「サンタクラリータ・ダイエット」とか、コメディーはよく[F]見る[/F]よ。', 'ドラマも好きだけど。', '「ウエストワールド」、「ハンドメイズ・テール」とかね。']
#
# Different number of sentences found in the following example:
# ['So, Did you even realize that Comedy Central has cancelled over 100 shows since 1989?', '?']
# ['コメディー・セントラルは、1989年以降100回以上も公演をキャンセルしたことを知っていましたか?']
# ['コメディー・セントラルは、1989年以降100回以上も公演をキャンセルしたことを知ってた?']
# ['コメディー・セントラルは、1989年以降100回以上も公演をキャンセルしたことを[F]知っていました[/F]か?']
# ['コメディー・セントラルは、1989年以降100回以上も公演をキャンセルしたことを[F]知ってた[/F]?']
#
# Different number of sentences found in the following example:
# ['I do.', 'You yourself?', 'And I believe that google is the largest search engine, although Youtube is owned by Google if I am not mistaken.']
# ['ええ。', 'あなたは?', 'Googleは最大の検索エンジンだと思います。', 'でも確かYoutubeはGoogleが所有していますよ。']
# ['うん。', 'あなたは?', 'Googleは最大の検索エンジンだと思う。', 'でも確かYoutubeはGoogleが所有しているよ。']
# ['ええ。', 'あなたは?', 'Googleは最大の検索エンジンだと[F]思います[/F]。', 'でも確かYoutubeはGoogleが[F]所有しています[/F]よ。']
# ['うん。', 'あなたは?', 'Googleは最大の検索エンジンだと[F]思う[/F]。', 'でも確かYoutubeはGoogleが[F]所有している[/F]よ。']
#
# Different number of sentences found in the following example:
# ['I see your point it does look like a silly thing to do, do you like Tim Duncan, he is also another great player.']
# ['言いたいことは分かりますよ。', 'そんなことをするのは馬鹿げているように見えます。', 'ティム・ダンカンは好きですか?', '彼も素晴らしいプレイヤーです。']
# ['言いたいことは分かるよ。', 'そんなことをするのは馬鹿げているように見える。', 'ティム・ダンカンは好きかい?', '彼も素晴らしいプレイヤーだ。']
# ['[F]言いたい[/F]ことは[F]分かります[/F]よ。', 'そんなことを[F]する[/F]のは馬鹿げているように[F]見えます[/F]。', 'ティム・ダンカンは[F]好きです[/F]か?', '彼も素晴らしいプレイヤー[F]です[/F]。']
# ['[F]言いたい[/F]ことは[F]分かる[/F]よ。', 'そんなことを[F]する[/F]のは馬鹿げているように[F]見える[/F]。', 'ティム・ダンカンは[F]好き[/F]かい?', '彼も素晴らしいプレイヤー[F]だ[/F]。']
#
# Different number of sentences found in the following example:
# ['Yeah same here, I like to be able to at least play every sport just a bit once.', 'Do you follow tennis at all?']
# ['私もそうです。', 'すべてのスポーツを最低でも1回はプレーしてみたいですね。', 'テニスは見ませんか?']
# ['私もそう。', 'すべてのスポーツを最低でも1回はプレーしてみたいね。', 'テニスは見ないの?']
# ['私もそう[F]です[/F]。', 'すべてのスポーツを最低でも1回は[F]プレーしてみたいです[/F]ね。', 'テニスは[F]見ません[/F]か?']
# ['私もそう。', 'すべてのスポーツを最低でも1回は[F]プレーしてみたい[/F]ね。', 'テニスは[F]見ない[/F]の?']
#
# Different number of sentences found in the following example:
# ["I've heard of these cocktail places that do drinks using liquid nitrogen, you're meant to let it evaporate before ingesting.", "I can imagine when you've had a few drinks your sense of caution get lost."]
# ['液体窒素を使ったドリンクを出すカクテルバーについて聞いたことがありますよ。', '飲む前に蒸発させるためらしいです。', '何杯か飲んだら注意力が失われるでしょうね。']
# ['液体窒素を使ったドリンクを出すカクテルバーについて聞いたことがあるよ。', '飲む前に蒸発させるためらしい。', '何杯か飲んだら注意力が失われるだろうね。']
# ['液体窒素を使ったドリンクを出すカクテルバーについて[F]聞いた[/F]ことが[F]あります[/F]よ。', '飲む前に蒸発させるためらしい[F]です[/F]。', '何杯か飲んだら注意力が[F]失われるでしょう[/F]ね。']
# ['液体窒素を使ったドリンクを出すカクテルバーについて[F]聞いた[/F]ことが[F]ある[/F]よ。', '飲む前に蒸発させるためらしい。', '何杯か飲んだら注意力が[F]失われるだろう[/F]ね。']
#
# Different number of sentences found in the following example:
# ["Yah, it's quite a bit larger than a baseball for sure, I've never seen a softball video game though, have you?"]
# ['絶対に野球よりもずっと大きいですね。', 'でもソフトボールのテレビゲームを見たことがありませんが、あなたはどうですか?']
# ['絶対に野球よりもずっと大きいね。', 'でもソフトボールのテレビゲームを見たことがないけど、あなたはどう?']
# ['絶対に野球よりもずっと[F]大きいです[/F]ね。', 'でもソフトボールのテレビゲームを見たことが[F]ありません[/F]が、あなたはどう[F]です[/F]か?']
# ['絶対に野球よりもずっと[F]大きい[/F]ね。', 'でもソフトボールのテレビゲームを見たことが[F]ない[/F]けど、あなたはどう?']
#
# Different number of sentences found in the following example:
# ['So what would be your team, which jersey would you want for a tweet?']
# ['あなたのチームの調子はどうですか?', 'ツイート用にどのユニフォームが欲しいですか?']
# ['あなたのチームの調子はどう?', 'ツイート用にどのユニフォームが欲しい?']
# ['あなたのチームの調子はどう[F]です[/F]か?', 'ツイート用にどのユニフォームが[F]欲しいです[/F]か?']
# ['あなたのチームの調子はどう?', 'ツイート用にどのユニフォームが[F]欲しい[/F]?']
#
# Different number of sentences found in the following example:
# ['I did and loved it so much, and you?']
# ['やってみてとても気に入りました。', 'あなたはどうですか?']
# ['やってみてとても気に入った。', 'あなたはどう?']
# ['やってみてとても[F]気に入りました[/F]。', 'あなたはどう[F]です[/F]か?']
# ['やってみてとても[F]気に入った[/F]。', 'あなたはどう?']
#
# Different number of sentences found in the following example:
# ['Wow that is really fast, I bet you can get to your destination in no time, do you like to travel?']
# ['それは本当に速いですね。', 'すぐに目的地に着けます。', '旅行は好きですか?']
# ['それは本当に速いね。', 'すぐに目的地に着ける。', '旅行は好き?']
# ['それは本当に[F]速いです[/F]ね。', 'すぐに目的地に[F]着けます[/F]。', '旅行は[F]好きです[/F]か?']
# ['それは本当に[F]速い[/F]ね。', 'すぐに目的地に[F]着ける[/F]。', '旅行は[F]好き[/F]?']
#
# Different number of sentences found in the following example:
# ['Yes it is.', 'Mostly by oceans but also lakes, rivers, and other sources!', 'Well it was lovely getting to talk with you!']
# ['確かに、ほとんど海ですが、湖、川、他の水源による場合もあります!', '話せて本当に楽しかったですよ。']
# ['確かに、ほとんど海だけど、湖、川、他の水源による場合もある!', '話せて本当に楽しかったよ。']
# ['確かに、ほとんど海[F]です[/F]が、湖、川、他の水源による場合も[F]あります[/F]!', '[F]話せて[/F]本当に[F]楽しかったです[/F]よ。']
# ['確かに、ほとんど海[F]だ[/F]けど、湖、川、他の水源による場合も[F]ある[/F]!', '[F]話せて[/F]本当に[F]楽しかった[/F]よ。']
#
# Different number of sentences found in the following example:
# ['Wow great information, I will have to try that sometime.', 'Do you like to eat fish or even go fishing?']
# ['素晴らしい情報です。', 'いつか試してみないといけません。', '魚を食べたり、あるいは釣りに行くのは好きですか?']
# ['素晴らしい情報だ。', 'いつか試してみないと。', '魚を食べたり、あるいは釣りに行くのは好き?']
# ['素晴らしい情報[F]です[/F]。', 'いつか試してみないと[F]いけません[/F]。', '魚を食べたり、あるいは釣りに行くのは[F]好き[/F]ですか?']
# ['素晴らしい情報[F]だ[/F]。', 'いつか試してみないと。', '魚を食べたり、あるいは釣りに行くのは[F]好き[/F]?']
#
# Different number of sentences found in the following example:
# ['I will have to check that out lol!', 'It was so nice chatting with you, enjoy your weekend!']
# ['見てみなくては!', '話せて楽しかったですよ。', '週末を楽しんでくださいね!']
# ['見てみなきゃ!', '話せて楽しかったよ。', '週末を楽しんでね!']
# ['[F]見てみなくては[/F]!', '[F]話せて[/F][F]楽しかったです[/F]よ。', '週末を[F]楽しんでください[/F]ね!']
# ['[F]見てみなきゃ[/F]!', '[F]話せて[/F][F]楽しかった[/F]よ。', '週末を[F]楽しんで[/F]ね!']
#
# Different number of sentences found in the following example:
# ['That is a bit invasive, they can track your location and all, your cellphone can get hacked and then a stalker will know your every move']
# ['それは少し侵害ですね。', '位置情報などを追跡できれば、携帯電話がハッキングされて、ストーカーにすべての動きを知られてしまう可能性があります']
# ['それは少し侵害だね。', '位置情報などを追跡できれば、携帯電話がハッキングされて、ストーカーにすべての動きを知られてしまう可能性がある']
# ['それは少し侵害[F]です[/F]ね。', '位置情報などを追跡できれば、携帯電話がハッキングされて、ストーカーにすべての動きを知られてしまう可能性が[F]あります[/F]']
# ['それは少し侵害[F]だ[/F]ね。', '位置情報などを追跡できれば、携帯電話がハッキングされて、ストーカーにすべての動きを知られてしまう可能性が[F]ある[/F]']
#
# Different number of sentences found in the following example:
# ["Yeah and also, many people don't know there's really no correlation between connection quality and service bars either.", "To answer your question, I'm not sure.", 'What does Minnie Mouse stand for?']
# ['はい。', 'あと接続の質とサービスの制約にまったく相関関係がないことを知らない人が多いですね。', 'あなたの質問ですが、答えは分かりません。', 'ミニーマウスってどういうことですか?']
# ['うん。', 'あと接続の質とサービスの制約にまったく相関関係がないことを知らない人が多いね。', 'あなたの質問だけど、答えは分からない。', 'ミニーマウスってどういうこと?']
# ['はい。', 'あと接続の質とサービスの制約にまったく相関関係がないことを知らない人が[F]多いです[/F]ね。', 'あなたの[F]質問です[/F]が、答えは[F]分かりません[/F]。', 'ミニーマウスってどういうこと[F]です[/F]か?']
# ['うん。', 'あと接続の質とサービスの制約にまったく相関関係がないことを知らない人が[F]多い[/F]ね。', 'あなたの質問[F]だ[/F]けど、答えは[F]分からない[/F]。', 'ミニーマウスってどういうこと?']
#
# Different number of sentences found in the following example:
# ["I do too, I don't particularly like him.", 'Did you vote last election']
# ['同感です。', '彼のことが特別に好きなわけではありません。', '前回の選挙では彼に投票しましたか?']
# ['同感だよ。', '彼のことが特別に好きなわけではない。', '前回の選挙では彼に投票したの?']
# ['同感[F]です[/F]。', '彼のことが特別に好きなわけでは[F]ありません[/F]。', '前回の選挙では彼に[F]投票しました[/F]か?']
# ['同感[F]だ[/F]よ。', '彼のことが特別に好きなわけでは[F]ない[/F]。', '前回の選挙では彼に[F]投票した[/F]の?']
#
# Different number of sentences found in the following example:
# ['Hey how is it going, you ever cook a turkey during Thanksgiving?']
# ['こんにちは、調子はいかがですか？', 'サンクスギビングではターキーを焼きますか？']
# ['やあ、調子はどう？', 'サンクスギビングではターキーを焼く？']
# ['こんにちは、調子はいかが[F]です[/F]か？', 'サンクスギビングではターキーを[F]焼きます[/F]か？']
# ['やあ、調子はどう？', 'サンクスギビングではターキーを[F]焼く[/F]？']
#
# Different number of sentences found in the following example:
# ["I know, I haven't seen it.", 'How lucky to find baseball cards in your grandfathers attic worth 3 million dollars!', 'Good chat!', '!']
# ['見たことがありません。', 'おじいちゃんの屋根裏部屋で300万ドルの価値があるベースボールカードを見つけるとはなんてラッキーなんでしょう!', '話せて楽しかったです!']
# ['見たことがない。', 'じいちゃんの屋根裏部屋で300万ドルの価値があるベースボールカードを見つけるとはなんてラッキーなんだ!', '話せて楽しかった!']
# ['[F]見た[/F]ことが[F]ありません[/F]。', 'おじいちゃんの屋根裏部屋で300万ドルの価値があるベースボールカードを[F]見つける[/F]とはなんてラッキー[F]なんでしょう[/F]!', '話せて[F]楽しかったです[/F]!']
# ['[F]見た[/F]ことが[F]ない[/F]。', 'じいちゃんの屋根裏部屋で300万ドルの価値があるベースボールカードを[F]見つける[/F]とはなんてラッキー[F]なんだ[/F]!', '話せて[F]楽しかった[/F]!']
#
# Different number of sentences found in the following example:
# ['I did, but I rather watch the games than to play them on a video game console, do you like baseball?']
# ['ええ。', 'でもテレビゲーム機でプレーするよりも試合を見るほうが好きです。', '野球は好きですか?']
# ['うん。', 'でもテレビゲーム機でプレーするよりも試合を見るほうが好きだな。', '野球は好きかい?']
# ['ええ。', 'でもテレビゲーム機でプレーするよりも試合を見るほうが[F]好きです[/F]。', '野球は[F]好きです[/F]か?']
# ['うん。', 'でもテレビゲーム機でプレーするよりも試合を見るほうが[F]好きだ[/F]な。', '野球は[F]好き[/F]かい?']
#
# Different number of sentences found in the following example:
# ["Have you ever played the game yourself, I have not, I'm not originally from the US."]
# ['自分でゲームをプレーしたことがありますか？', '私はアメリカ出身ではありませんので、プレーしたことはありません。']
# ['自分でゲームをプレーしたことがある？', '私はアメリカ出身ではないので、プレーしたことはない。']
# ['自分でゲームをプレーしたことが[F]あります[/F]か？', '私はアメリカ出身では[F]ありません[/F]ので、プレーしたことは[F]ありません[/F]。']
# ['自分でゲームをプレーしたことが[F]ある[/F]？', '私はアメリカ出身では[F]ない[/F]ので、プレーしたことは[F]ない[/F]。']
#
# Different number of sentences found in the following example:
# ["That's unusual, I've never thought of heavy metal as literature, but ok. Who's your favorite author?"]
# ['それは変わっていますね。', 'ヘビーメタルを文学だと考えたことはありませんでした。', '好きな作家は誰ですか?']
# ['それは変わっているね。', 'ヘビーメタルを文学だと考えたことはなかった。', '好きな作家は誰?']
# ['それは[F]変わっています[/F]ね。', 'ヘビーメタルを文学だと考えたことは[F]ありませんでした[/F]。', '[F]好きな[/F]作家は誰[F]です[/F]か?']
# ['それは[F]変わっている[/F]ね。', 'ヘビーメタルを文学だと考えたことは[F]なかった[/F]。', '[F]好きな[/F]作家は誰?']
#
# Different number of sentences found in the following example:
# ['Then maybe you could try the deaf rapper, Signmark.', 'He rhymes in sign language!', "You don't have to listen at all!", "I'm going to go try to find some on the internet.", 'Goodbye!']
# ['サインマークっていう聴覚障害のラッパーを聞いてみるといいかもしれません。', '彼は手話で韻を踏むから、耳で聞く必要は全くありません!', 'インターネットで少し探してみますよ。', 'またね!']
# ['サインマークっていう聴覚障害のラッパーを聞いてみるといいかもしれないね。', '彼は手話で韻を踏むから、耳で聞く必要は全くない!', 'インターネットで少し探してみるよ。', 'またね!']
# ['サインマークっていう聴覚障害のラッパーを[F]聞いてみる[/F]といいかも[F]しれません[/F]。', '彼は手話で韻を踏むから、耳で聞く必要は全く[F]ありません[/F]!', 'インターネットで少し[F]探してみます[/F]よ。', 'またね!']
# ['サインマークっていう聴覚障害のラッパーを[F]聞いてみる[/F]といいかも[F]しれない[/F]ね。', '彼は手話で韻を踏むから、耳で聞く必要は全く[F]ない[/F]!', 'インターネットで少し[F]探してみる[/F]よ。', 'またね!']
#
# Different number of sentences found in the following example:
# ["Yeah that's horrible!", 'interesting that the term "robotic" was created by a science fiction author, you\'d think that it would have been an actual science term, and this happened back in 1941 haha']
# ['それはひどいですね!', '興味深いことに、「ロボティック」っていう言葉は、サイエンスフィクションの作家が作り出した言葉です。', '本物の科学用語だったと思っているでしょうが、1941年の話です。']
# ['それはひどい!', '興味深いことに、「ロボティック」っていう言葉は、サイエンスフィクションの作家が作り出した言葉だ。', '本物の科学用語だったと思っているだろうけど、1941年の話だ。']
# ['それは[F]ひどいです[/F]ね!', '興味深いことに、「ロボティック」っていう言葉は、サイエンスフィクションの作家が作り出した言葉[F]です[/F]。', '本物の科学用語だったと思っている[F]でしょう[/F]が、1941年の話[F]です[/F]。']
# ['それは[F]ひどい[/F]!', '興味深いことに、「ロボティック」っていう言葉は、サイエンスフィクションの作家が作り出した言葉[F]だ[/F]。', '本物の科学用語だったと思っている[F]だろう[/F]けど、1941年の話[F]だ[/F]。']
#
# Different number of sentences found in the following example:
# ['I didnt, he has a great voice!', 'you know that Stephen Fry is also a game narrator, he narrater the voice for some games']
# ['いいえ。', '彼の声は素晴らしいですね!', 'Stephen Flyもゲーム解説者で、数試合の解説を務めています']
# ['いいえ。', '彼の声は素晴らしいね!', 'Stephen Flyもゲーム解説者で、数試合の解説を務めている']
# ['いいえ。', '彼の声は[F]素晴らしいです[/F]ね!', 'Stephen Flyもゲーム解説者で、数試合の解説を[F]務めています[/F]']
# ['いいえ。', '彼の声は[F]素晴らしい[/F]ね!', 'Stephen Flyもゲーム解説者で、数試合の解説を[F]務めている[/F]']
#
# Different number of sentences found in the following example:
# ['Talented guy, what are your thoughts on the goatees some of the pleyers grow?']
# ['才能にあふれた男です。', '一部の選手がはやしているヤギひげについてどう思いますか。']
# ['才能にあふれた男だ。', '一部の選手がはやしているヤギひげについてどう思う。']
# ['才能にあふれた男[F]です[/F]。', '一部の選手がはやしているヤギひげについてどう[F]思います[/F]か。']
# ['才能にあふれた男[F]だ[/F]。', '一部の選手がはやしているヤギひげについてどう[F]思う[/F]。']
#
# Different number of sentences found in the following example:
# ['Hi.', 'This is George.', 'I think we talked on the phone a few days ago about my trip to Grande El something, I think?']
# ['こんにちは、ジョージです。', '数日前、グランデ・エルなんとかへの旅行のことで電話で話したと思いますが？']
# ['やあ、ジョージだよ。', '数日前、グランデ・エルなんとかへの旅行のことで電話で話したと思うんだけど？']
# ['こんにちは、ジョージ[F]です[/F]。', '数日前、グランデ・エルなんとかへの旅行のことで電話で[F]話したと思います[/F]が？']
# ['やあ、ジョージ[F]だ[/F]よ。', '数日前、グランデ・エルなんとかへの旅行のことで電話で[F]話したと思うんだ[/F]けど？']
#
# Different number of sentences found in the following example:
# ['Oh, okay.', "So I wouldn't need to call back in again.", 'I can just do it online?']
# ['ふーん、分かりました。', 'ではまた掛け直さなくても、ネットですればいいですね。']
# ['ふーん、分かった。', 'じゃあまた掛け直さなくても、ネットですればいいね。']
# ['ふーん、[F]分かりました[/F]。', 'ではまた掛け直さなくても、ネットですれば[F]いいです[/F]ね。']
# ['ふーん、[F]分かった[/F]。', 'じゃあまた掛け直さなくても、ネットですれば[F]いい[/F]ね。']
#
# Different number of sentences found in the following example:
# ["Oh, most definitely, it's possible.", 'So let me also tell you the options that we have, because before, we only had either pay cash, or either pay in points, but now we have the new option.']
# ['あぁ、もちろん、できますよ。', 'では、提供しているオプションについても説明させてください。', '以前は現金での支払いか、ポイントでの支払いしかありませんでしたが、新しい選択肢ができましたので。']
# ['あぁ、もちろん、できるよ。', 'じゃあ、提供しているオプションについても説明させて。', '以前は現金での支払いか、ポイントでの支払いしかなかったけど、新しい選択肢ができたから。']
# ['あぁ、もちろん、[F]できます[/F]よ。', 'では、提供しているオプションについても[F]説明させてください[/F]。', '以前は現金での支払いか、ポイントでの支払いしか[F]ありませんでした[/F]が、新しい選択肢が[F]できました[/F]ので。']
# ['あぁ、もちろん、[F]できる[/F]よ。', 'じゃあ、提供しているオプションについても[F]説明させて[/F]。', '以前は現金での支払いか、ポイントでの支払いしか[F]なかった[/F]けど、新しい選択肢が[F]できた[/F]から。']
#
# Different number of sentences found in the following example:
# ["Okay, great, so let's hope I'll be there bright and early tomorrow."]
# ['ええ、良いですよ。', 'では明日は朝早く行くように頑張ります。']
# ['うん、良いよ。', 'じゃあ明日は朝早く行くように頑張る。']
# ['ええ、[F]良いです[/F]よ。', 'では明日は朝早く[F]行く[/F]ように[F]頑張ります[/F]。']
# ['うん、[F]良い[/F]よ。', 'じゃあ明日は朝早く[F]行く[/F]ように[F]頑張る[/F]。']
#
# Different number of sentences found in the following example:
# ['Yes, I did.', "And just for our own company policy, and to avoid any mistakes, we're gonna go ahead and repeat it phonetically, okay?", "So, it'll be John."]
# ['ええ、しましたよ。', 'それと、会社の規約のためと、間違いを避けるため、もう一度読みましょう。', 'いいですか？', 'それで、ジョンですね。']
# ['うん、したよ。', 'それと、会社の規約のためと、間違いを避けるため、もう一度読もう。', 'いい？', 'それで、ジョンだね。']
# ['ええ、[F]しました[/F]よ。', 'それと、会社の規約のためと、間違いを避けるため、もう一度[F]読みましょう[/F]。', '[F]いいです[/F]か？', 'それで、ジョン[F]です[/F]ね。']
# ['うん、[F]した[/F]よ。', 'それと、会社の規約のためと、間違いを避けるため、もう一度[F]読もう[/F]。', '[F]いい[/F]？', 'それで、ジョン[F]だ[/F]ね。']
#
# Different number of sentences found in the following example:
# ['Okay, is this going to take long, because I got my kids to pick up from school?']
# ['ねえ、これって時間がかかりますか？', '子供たちを学校に迎えに行かないといけませんので。']
# ['ねえ、これって時間かかる？', '子供たちを学校に迎えに行かないといけないので。']
# ['ねえ、これって時間が[F]かかります[/F]か？', '子供たちを学校に迎えに行かないと[F]いけません[/F]ので。']
# ['ねえ、これって時間[F]かかる[/F]？', '子供たちを学校に迎えに行かないと[F]いけない[/F]ので。']
#
# Different number of sentences found in the following example:
# ['Oh, okay.', 'Not a problem.', 'So let me check the details here, let me check my system.']
# ['へえ、そうですか。', '大丈夫ですよ。', 'では、詳細を確認させてください。', 'システムを確認しますね。']
# ['ふーん、そう。', '大丈夫だよ。', 'じゃあ、詳細を確認させて。', 'システムを確認するね。']
# ['へえ、そう[F]です[/F]か。', '[F]大丈夫です[/F]よ。', 'では、詳細を[F]確認させてください[/F]。', 'システムを[F]確認します[/F]ね。']
# ['ふーん、そう。', '[F]大丈夫だ[/F]よ。', 'じゃあ、詳細を[F]確認させて[/F]。', 'システムを[F]確認する[/F]ね。']
#
# Different number of sentences found in the following example:
# ['And also I wanted to know if you guys provide any type of airport shuttle and if you guys can accommodate me and give me an early check-in, please.']
# ['それと、空港送迎のシャトルがあるか、宿泊できるか、アーリーチェックインができるかを知りたかったんですが。', 'お願いします。']
# ['それと、空港送迎のシャトルがあるか、宿泊できるか、アーリーチェックインができるかを知りたかったんだけど。', 'お願い。']
# ['それと、空港送迎のシャトルがあるか、宿泊できるか、アーリーチェックインができるかを[F]知りたかったんです[/F]が。', '[F]お願いします[/F]。']
# ['それと、空港送迎のシャトルがあるか、宿泊できるか、アーリーチェックインができるかを[F]知りたかったんだ[/F]けど。', '[F]お願い[/F]。']
#
# Different number of sentences found in the following example:
# ['Oh, Porto Le Grando?', 'Yeah.', "That must've been me.", 'Are you excited?']
# ['え、ポルト・レ・グランド？', 'そうですね、たぶん私です。', '楽しみですか？']
# ['え、ポルト・レ・グランド？', 'そうだね、たぶん私だ。', '楽しみ？']
# ['え、ポルト・レ・グランド？', 'そう[F]です[/F]ね、たぶん私[F]です[/F]。', '[F]楽しみです[/F]か？']
# ['え、ポルト・レ・グランド？', 'そう[F]だ[/F]ね、たぶん私[F]だ[/F]。', '[F]楽しみ[/F]？']
#
# Different number of sentences found in the following example:
# ["Alright, so I'm putting that CVV number onto my dial-pad and yup, there you go, go ahead and please proceed."]
# ['オッケー、今そのCVV番号をダイヤルパッドに入力していますよ。', 'よし、できました、進めてください。']
# ['オッケー、今そのCVV番号をダイヤルパッドに入力しているよ。', 'よし、できた、進めて。']
# ['オッケー、今そのCVV番号をダイヤルパッドに[F]入力しています[/F]よ。', 'よし、[F]できました[/F]、[F]進めてください[/F]。']
# ['オッケー、今そのCVV番号をダイヤルパッドに[F]入力している[/F]よ。', 'よし、[F]できた[/F]、[F]進めて[/F]。']
#
# Different number of sentences found in the following example:
# ['Yes, I was, I had a blocked artery and I was exerting myself when shoveling gravel.', 'It was very heavy and I had to go to the emergency room with my son and my daughter.']
# ['ええ、そうですよ。', '動脈閉塞です。', '砂利を掘って一生懸命仕事をしていました。', 'ものすごく重くて、息子と娘に付き添われて救急に行かないといけませんでした。']
# ['うん、そうだよ。', '動脈閉塞です。', '砂利を掘って一生懸命仕事をしていた。', 'ものすごく重くて、息子と娘に付き添われて救急に行かないといけなかった。']
# ['ええ、そう[F]です[/F]よ。', '動脈閉塞です。', '砂利を掘って一生懸命仕事を[F]していました[/F]。', 'ものすごく重くて、息子と娘に付き添われて救急に[F]行かないといけませんでした[/F]。']
# ['うん、そう[F]だ[/F]よ。', '動脈閉塞です。', '砂利を掘って一生懸命仕事を[F]していた[/F]。', 'ものすごく重くて、息子と娘に付き添われて救急に[F]行かないといけなかった[/F]。']
#
# Different number of sentences found in the following example:
# ["Yeah, Joey, about that, I don't really feel very comfortable giving out all those details, cause I had a problem a couple months ago with that.", 'I gave out my information to this']
# ['ええ、ジョーイー。', 'そのことなんですが、全部の情報を伝えるのはちょっと不安です。', 'このことで数か月前にトラブルに遭ったので。', '情報を伝えました']
# ['うん、ジョーイー。', 'そのことなんだけど、全部の情報を伝えるのはちょっと不安だ。', 'このことで数か月前にトラブルに遭ったので。', '情報を伝えた']
# ...
# ['はい、聞いて。', 'たった今スマホにメッセージが届いて、金額が銀行から既に引き落とされたって書いてある。', 'これって部屋がもう予約されたっていうこと？']
# ['はい、[F]聞いてください[/F]。', 'たった今スマホにメッセージが届いて、金額が銀行から既に引き落とされたと[F]書いてあります[/F]。', 'これって部屋がもう予約されたっていうこと[F]です[/F]か？']
# ['はい、[F]聞いて[/F]。', 'たった今スマホにメッセージが届いて、金額が銀行から既に引き落とされたって[F]書いてある[/F]。', 'これって部屋がもう予約されたっていうこと？']
#
# Different number of sentences found in the following example:
# ['Also please bear in mind that all this information provided is strictly confidential.', 'This information will be only used for our internal usage, so I will put all the information in our system']
# ['それと、提供された情報はすべて極秘事項だということを覚えておいてください。', 'この情報は社外秘です。', 'では、情報をシステムに入力しますね']
# ['それと、提供された情報はすべて極秘事項だということを覚えておいて。', 'この情報は社外秘だ。', 'じゃあ、情報をシステムに入力するね']
# ['それと、提供された情報はすべて極秘事項だということを[F]覚えておいてください[/F]。', 'この情報は社外秘[F]です[/F]。', 'では、情報をシステムに[F]入力します[/F]ね']
# ['それと、提供された情報はすべて極秘事項だということを[F]覚えておいて[/F]。', 'この情報は社外秘[F]だ[/F]。', 'じゃあ、情報をシステムに[F]入力する[/F]ね']
#
# Different number of sentences found in the following example:
# ['When should I submit the passport, and how many days does it take for a visa stamp and stuff like that?']
# ['パスポートはいつ提出したら良いですか？', 'それから、ビザのハンコとかそういうものにはどれくらいの時間がかかりますか？']
# ['パスポートはいつ提出したら良い？', 'それと、ビザのハンコとかそういうものにはどれくらいの時間がかかるの？']
# ['パスポートはいつ提出したら[F]良いです[/F]か？', 'それから、ビザのハンコとかそういうものにはどれくらいの時間が[F]かかります[/F]か？']
# ['パスポートはいつ提出したら[F]良い[/F]？', 'それと、ビザのハンコとかそういうものにはどれくらいの時間が[F]かかる[/F]の？']
#
# Different number of sentences found in the following example:
# ['Yeah, Joey, about that, I do have a problem with giving out my personal information, because I had a situation that was very uncomfortable a couple of months ago.']
# ['ええ、ジョーイー、そのことですが、自分の個人情報を伝えるのは嫌です。', '数か月前にとても嫌な状況になったので。']
# ['うん、ジョーイー、そのことだけど、自分の個人情報を伝えるのは嫌だ。', '数か月前にとても嫌な状況になったので。']
# ['ええ、ジョーイー、そのこと[F]です[/F]が、自分の個人情報を[F]伝える[/F]のは[F]嫌です[/F]。', '数か月前にとても嫌な状況になったので。']
# ['うん、ジョーイー、そのこと[F]だ[/F]けど、自分の個人情報を[F]伝える[/F]のは[F]嫌だ[/F]。', '数か月前にとても嫌な状況になったので。']
#
# Different number of sentences found in the following example:
# ['But I think I might need an early check-in in the room, because I think my flight arrived kind of early.']
# ['でも多分部屋のアーリーチェックインが必要だと思います。', 'フライトが少し早く到着するはずですので。']
# ['でも多分部屋のアーリーチェックインが必要だと思う。', 'フライトがちょっと早く到着するはずだから。']
# ['でも多分部屋のアーリーチェックインが必要だと[F]思います[/F]。', 'フライトが少し早く到着するはず[F]です[/F]ので。']
# ['でも多分部屋のアーリーチェックインが必要だと[F]思う[/F]。', 'フライトがちょっと早く到着するはず[F]だ[/F]から。']
#
# Different number of sentences found in the following example:
# ["Oh, okay, so this month I'll still get the paper mail, then?"]
# ['へえ、分かりましたね。', 'では今月はまだ手紙で送られてくるんですね？']
# ['ふーん、分かった。', 'じゃあ今月はまだ手紙で送られてくるんだね？']
# ['へえ、[F]分かりました[/F]ね。', 'では今月はまだ手紙で[F]送られてくるんです[/F]ね？']
# ['ふーん、[F]分かった[/F]。', 'じゃあ今月はまだ手紙で[F]送られてくるんだ[/F]ね？']
#
# Different number of sentences found in the following example:
# ['Wow!', "That does sound good because it's pretty much summertime.", 'So where is your office?']
# ['おう、夏らしい時期なので良さそうですね。', 'さて、あなたのオフィスはどこですか？']
# ['おう、夏らしい時期なので良さそうだね。', 'さて、あなたのオフィスはどこ？']
# ['おう、夏らしい時期なので[F]良さそうです[/F]ね。', 'さて、あなたのオフィスはどこ[F]です[/F]か？']
# ['おう、夏らしい時期なので[F]良さそうだ[/F]ね。', 'さて、あなたのオフィスはどこ？']
#
# Different number of sentences found in the following example:
# ['Okay.', 'Now, Mister Stewart, thanks for that information, there.', 'Okay.', 'I do have that down.', "Now, I do need your date of birth as well, if you don't mind?"]
# ['そうですね。', 'さて、スチュワートさん、情報提供ありがとうございました。', 'わかりました、記入しました。', 'では、よければあなたの生年月日も教えてくださいますか？']
# ['そうだね。', 'さて、スチュワートさん、情報提供ありがとう。', 'わかった、記入した。', 'では、よければあなたの生年月日も教えて？']
# ['そうですね。', 'さて、スチュワートさん、情報提供[F]ありがとうございました[/F]。', '[F]わかりました[/F]、[F]記入しました[/F]。', 'では、よければあなたの生年月日も[F]教えてくださいます[/F]か？']
# ['そうだね。', 'さて、スチュワートさん、情報提供[F]ありがとう[/F]。', '[F]わかった[/F]、[F]記入した[/F]。', 'では、よければあなたの生年月日も[F]教えて[/F]？']
#
# Different number of sentences found in the following example:
# ['You can carry shaving foam and toothpaste in the cabin because we know that after you eat, you definitely want to go ahead and you know, go brush your teeth and stuff like that, so that is allowed.', 'And']
# ['シェービングフォームや歯磨き粉は機内に持ち込めます。', '食事をした後は、歯磨きなどをしたくなりますけど、それも可能です。', 'また']
# ['シェービングフォームや歯磨き粉は機内に持ち込める。', '食事をした後は、歯磨きなどをしたくなるけど、それも可能。', 'また']
# ['シェービングフォームや歯磨き粉は機内に[F]持ち込めます[/F]。', '食事をした後は、歯磨きなどを[F]したくなります[/F]けど、それも可能[F]です[/F]。', 'また']
# ['シェービングフォームや歯磨き粉は機内に[F]持ち込める[/F]。', '食事をした後は、歯磨きなどを[F]したくなる[/F]けど、それも可能。', 'また']
#
# Different number of sentences found in the following example:
# ['Certainly, fiftieth anniversary.', 'First of all, I want to say congratulations!', 'Okay, for your fiftieth anniversary, though...']
# ['確かに、五十周年。', 'まずは、おめでとうございます！', 'と言いたいです。', 'さて、50周年記念と言いましても...']
# ['確かに、五十周年。', 'まずは、おめでとう！', 'と言いたい。', 'さて、50周年記念と言っても...']
# ['確かに、五十周年。', 'まずは、[F]おめでとうございます[/F]！', 'と[F]言いたいです[/F]。', 'さて、50周年記念と[F]言いましても[/F]...']
# ['確かに、五十周年。', 'まずは、[F]おめでとう[/F]！', 'と[F]言いたい[/F]。', 'さて、50周年記念と[F]言っても[/F]...']
#
# Different number of sentences found in the following example:
# ['So please, I need some more information.', 'I need to know your flight number and also, well, you already gave me the time, so the flight number.']
# ['だから、もう少し情報が必要です。', 'あなたのフライトナンバーを教えてください。', 'また、時間はすでに教えていただきましたが、フライトナンバーも教えてください。']
# ['だから、もう少し情報が必要だ。', 'あなたのフライトナンバーを教えて。', 'また、時間はすでに教えていただいたが、フライトナンバーも教えて。']
# ['だから、もう少し情報が[F]必要です[/F]。', 'あなたのフライトナンバーを[F]教えてください[/F]。', 'また、時間はすでに[F]教えていただきました[/F]が、フライトナンバーも[F]教えてください[/F]。']
# ['だから、もう少し情報が[F]必要だ[/F]。', 'あなたのフライトナンバーを[F]教えて[/F]。', 'また、時間はすでに[F]教えていただいた[/F]が、フライトナンバーも[F]教えて[/F]。']
#
# Different number of sentences found in the following example:
# ['Let me have your contact details, email and phone number, so that I can look for it on my records, or if not, I can put it in our records.']
# ['あなたの連絡先、電子メールと電話番号を教えてください。', 'そうすれば、私の記録から探せますし、なければ、私たちの記録に載せることもできます。']
# ['あなたの連絡先、電子メールと電話番号を教えて。', 'そうすれば、私の記録から探せるし、なければ、私たちの記録に載せることもできる。']
# ['あなたの連絡先、電子メールと電話番号を[F]教えてください[/F]。', 'そうすれば、私の記録から[F]探せます[/F]し、なければ、私たちの記録に載せることも[F]できます[/F]。']
# ['あなたの連絡先、電子メールと電話番号を[F]教えて[/F]。', 'そうすれば、私の記録から[F]探せる[/F]し、なければ、私たちの記録に載せることも[F]できる[/F]。']
#
# Different number of sentences found in the following example:
# ['They go from shore to shore.', 'Alright.', 'Yeah.', "The system is freaking me up to make me reverse that transaction, and I'm gonna send you a coupon also for your"]
# ['海岸から海岸へと移動します 。', 'そう。', 'システムに苛立って、その取引を取り消して、あなたにもクーポンを送ります。']
# ['海岸から海岸へと移動する 。', 'そう。', 'システムに苛立って、その取引を取り消して、あなたにもクーポンを送る。']
# ['海岸から海岸へと[F]移動します[/F] 。', 'そう。', 'システムに苛立って、その取引を取り消して、あなたにもクーポンを[F]送ります[/F]。']
# ['海岸から海岸へと[F]移動する[/F] 。', 'そう。', 'システムに苛立って、その取引を取り消して、あなたにもクーポンを[F]送る[/F]。']
#
# Different number of sentences found in the following example:
# ["No, I don't think there's anything else that you can help me with over the phone.", "I just, yeah, I'll just write down my questions and have them ready for the assistant tomorrow, so."]
# ['他に電話で相談に乗ってもらえることはありません。', '質問を書き留めて、明日のアシスタントのために用意しておきます。']
# ['他に電話で相談に乗っていただけることはない。', '質問を書き留めて、明日のアシスタントのために用意しておく。']
# ['他に電話で相談に乗ってもらえることは[F]ありません[/F]。', '質問を書き留めて、明日のアシスタントのために[F]用意しておきます。', '[/F]']
# ['他に電話で相談に乗っていただけることは[F]ない[/F]。', '質問を書き留めて、明日のアシスタントのために[F]用意しておく[/F]。']
#
# Different number of sentences found in the following example:
# ['Sure.', 'Let me tell you all the details.', "Well, first of all, you're gonna get a complimentary pick-up and drop-off facility from the airport.", 'So this should be free shuttle.']
# ['もちろん、詳細をお話しします。', 'まず第一に、空港からの無料送迎施設を用意しています。', 'これは無料のシャトルになるはずです。']
# ['もちろん、詳細を話す。', 'まず第一に、空港からの無料送迎施設を用意している。', 'これは無料のシャトルになるはず。']
# ['もちろん、詳細を[F]お話しします[/F]。', 'まず第一に、空港からの無料送迎施設を[F]用意しています[/F]。', 'これは無料のシャトルになるはずです。']
# ['もちろん、詳細を[F]話す[/F]。', 'まず第一に、空港からの無料送迎施設を[F]用意している[/F]。', 'これは無料のシャトルになるはず。']
#
# Different number of sentences found in the following example:
# ['Certainly, send it to me.', 'Go ahead and take your time, send me that confirmation number to my e-mail as well.']
# ['わかりました。', 'それを私に送ってください。', '急ぎませんが、その確認番号を私のメールにも送ってください。']
# ['確かに。', 'それを私に送って。', '急がないが、その確認番号を私のメールにも送って。']
# ['[F]わかりました[/F]。', 'それを私に送ってください。', '急ぎませんが、その確認番号を私のメールにも[F]送ってください[/F]。']
# ['[F]確かに[/F]。', 'それを私に送って。', '急がないが、その確認番号を私のメールにも[F]送って[/F]。']
#
# Different number of sentences found in the following example:
# ["You don't have to worry about this.", "I am also going to send you an email with my ID confirming this, and, well, you don't have to worry about this.", 'So let me have your phone number and your email.']
# ['ご心配はいりません。', 'これを確認するためのIDを書いたメールを送ります。', 'ですから、ご心配はいりません。', 'それでは、電話番号とメールアドレスを頂けますか。']
# ['ご心配はいらない。', 'これを確認するためのIDを書いたメールを送る。', 'だから、心配はいりません。', 'それでは、電話番号とメールアドレスをいただけますか。']
# ['ご心配はいりません。', 'これを確認するためのIDを書いたメールを[F]送ります[/F]。', 'ですから、ご心配はいりません。', 'それでは、電話番号とメールアドレスを[F]頂けます[/F]か。']
# ['ご心配はいらない。', 'これを確認するためのIDを書いたメールを[F]送る[/F]。', 'だから、心配はいりません。', 'それでは、電話番号とメールアドレスを[F]いただけます[/F]か。']
#
# Different number of sentences found in the following example:
# ['Yes, of course.', 'Well, let me tell you.', 'Besides from the free WIFI and the chocolates, the champagne and the ocean front jacuzzi, on top of that, we are going to give you free shuttle,']
# ['はい、もちろんです。', '無料のWi-Fiや、チョコレートや、シャンパンや、海に面したジャグジー以外にも、無料のシャトルも提供しています。']
# ['はい、もちろん。', '無料のWi-Fiや、チョコレートや、シャンパンや、海に面したジャグジー以外にも、無料のシャトルも提供している。']
# ['はい、もちろんです。', '無料のWi-Fiや、チョコレートや、シャンパンや、海に面したジャグジー以外にも、無料のシャトルも[F]提供しています[/F]。']
# ['はい、もちろん。', '無料のWi-Fiや、チョコレートや、シャンパンや、海に面したジャグジー以外にも、無料のシャトルも[F]提供している[/F]。']
#
# Different number of sentences found in the following example:
# ['Okay, so what?', 'After growing the cotton, will you be providing customers who will purchase it or we have to sell it?']
# ['さて、それで綿花を栽培した後、それを購入してくれるお客様を提供してくれるのですか、それとも我々が販売しなければならないのですか。']
# ['さて、それで？', '綿花を栽培した後、それを買ってくれる客をいただけるのか、それとも我々が販売しなければならないのか。']
# ['さて、それで綿花を栽培した後、それを購入してくれるお客様を[F]提供してくれるのです[/F]か、それとも我々が販売しなければ[F]ならないのです[/F]か。']
# ['さて、それで？', '綿花を栽培した後、それを買ってくれる客を[F]いただける[/F]のか、それとも我々が販売しなければならないのか。']
#
# Different number of sentences found in the following example:
# ["We are very proud to say that everything is used only for internal use, so this way, when you call, you don't have to give all your information again.", 'We just pull it up with your phone number.']
# ['私たちは、すべてが社内でのみ使用されていると自負しています。', 'このようにしておけば、電話をかけてきたときに、情報をすべて再び伝える必要はありません。', '私たちはあなたの電話番号でそれを引き出すだけです。']
# ['私たちは、すべてが社内でのみ使用されていると自負している。', 'このようにしておけば、電話をかけてきたときに、情報をすべて再び伝える必要はない。', '私たちはあなたの電話番号でそれを引き出すだけだ。']
# ['私たちは、すべてが社内でのみ[F]使用されている[/F]と[F]自負しています[/F]。', 'このようにしておけば、電話をかけてきたときに、情報をすべて再び伝える必要はありません。', '私たちはあなたの電話番号でそれを引き出す[F]だけです[/F]。']
# ['私たちは、すべてが社内でのみ[F]使用されている[/F]と[F]自負している[/F]。', 'このようにしておけば、電話をかけてきたときに、情報をすべて再び伝える必要はない。', '私たちはあなたの電話番号でそれを引き出す[F]だけだ[/F]。']
#
# Different number of sentences found in the following example:
# ['name to know the outlets you are looking for.', "I'm going to give you an example, for example you can type San Francisco to know our partners in San Francisco."]
# ['の名前を入力すると、探しているアウトレットを知ることができます。', '例を挙げて説明します。', '例えば、「San Francisco」と入力すると、サンフランシスコのパートナー企業を知ることができます。']
# ['の名前を入力すると、探しているアウトレットを知ることができるの。', '例を挙げて説明する。', '例えば、「San Francisco」と入力すると、サンフランシスコのパートナー企業を知ることができる。']
# ['の名前を[F]入力する[/F]と、探しているアウトレットを知ることが[F]できます[/F]。', '例を挙げて[F]説明します[/F]。', '例えば、「San Francisco」と[F]入力する[/F]と、サンフランシスコのパートナー企業を知ることが[F]できます[/F]。']
# ['の名前を[F]入力する[/F]と、探しているアウトレットを知ることが[F]できる[/F]の。', '例を挙げて[F]説明する[/F]。', '例えば、「San Francisco」と[F]入力する[/F]と、サンフランシスコのパートナー企業を知ることが[F]できる[/F]。']
#
# Different number of sentences found in the following example:
# ['Now, all the tourists are very packed here.', "So, we don't want you to lose out on your room, that's why you got the charge and that is why you're going to get all those emails."]
# ['今、ここにはすべての観光客がとても混んでいます。', 'ですから、部屋に泊まるチャンスを逃してほしくないのです。', 'です。', 'そのために料金が発生し、このようなメールが送られてくるのです。']
# ['今、ここは観光客でとても混んでいる。', 'だから、部屋に泊まるチャンスを逃してほしくない。', 'そのために料金が発生し、このようなメールが送られてくる。']
# ['今、ここにはすべての観光客がとても[F]混んでいます[/F]。', 'ですから、部屋に泊まるチャンスを逃して[F]ほしくないのです[/F]。', 'です。', 'そのために料金が発生し、このようなメールが送られてくるのです。']
# ['今、ここは観光客でとても[F]混んでいる[/F]。', 'だから、部屋に泊まるチャンスを逃して[F]ほしくない[/F]。', 'そのために料金が発生し、このようなメールが送られてくる。']
#
# Different number of sentences found in the following example:
# ['He is gonna help you fill out the customer form, and the documents that will be required are gonna be the company and corporation certificate, the license to sell the propane and also your state-issued ID.']
# ['彼が客のフォームを書くのを手伝ってくれます。', '必要な書類は、会社や法人の証明書、プロパンガスを販売するためのライセンス、そして州が発行するIDです。']
# ['彼が客のフォームを書くのを手伝ってくれる。', '必要な書類は、会社や法人の証明書、プロパンガスを販売するためのライセンス、そして州が発行するIDだ。']
# ['彼が客のフォームを書くのを手伝ってくれます。', '必要な書類は、会社や法人の証明書、プロパンガスを販売するためのライセンス、そして州が発行するID[F]です[/F]。']
# ['彼が客のフォームを書くのを手伝ってくれる。', '必要な書類は、会社や法人の証明書、プロパンガスを販売するためのライセンス、そして州が発行するID[F]だ[/F]。']
#
# Different number of sentences found in the following example:
# ["No, you don't have to worry about that fee.", 'The bank is going to pay for all the additional costs.', 'So']
# ['いいえ、費用の心配はいりません。', '追加費用は、すべて銀行が支払いますので、']
# ['いいえ、費用の心配はいらない。', '追加費用は、すべて銀行が支払うので、']
# ['いいえ、費用の心配は[F]いりません[/F]。', '追加費用は、すべて銀行が[F]支払います[/F]ので、']
# ['いいえ、費用の心配は[F]いらない[/F]。', '追加費用は、すべて銀行が[F]支払う[/F]ので、']
#
# Different number of sentences found in the following example:
# ["You know what, it's not coming through.", 'I would like to write it down, please.', 'Can I have the confirmation number?']
# ['伝わらないんです。', '書き留めておきたいのですが、お願いします。', '確認番号を教えてください。']
# ['あのね、届かないんだ。', '書き留めておきたいんだが、どうか、確認番号を教えて。']
# ['伝わらないんです。', '書き留めて[F]おきたいのです[/F]が、お願いします。', '確認番号を[F]教えてください[/F]。']
# ['あのね、[F]届かない[/F]んだ。', '書き留めて[F]おきたい[/F]んだが、どうか、確認番号を[F]教えて[/F]。']
#
# Different number of sentences found in the following example:
# ["I'm also gonna send it to your email address and this is gonna be everything that you need to know, just as a reminder."]
# ['また、あなたのメールアドレスにも送ります。', 'これは、念のためあなたが知っておくべきことのすべてです。']
# ['また、あなたのメールアドレスにも送る。', 'これは、あなたが知っておくべきことのすべてだけど、念のため。']
# ['また、あなたのメールアドレスにも[F]送ります[/F]。', 'これは、念のためあなたが[F]知っておくべき[/F]ことのすべてです。']
# ['また、あなたのメールアドレスにも[F]送る[/F]。', 'これは、あなたが[F]知っておくべき[/F]ことのすべてだけど、念のため。']
#
# Different number of sentences found in the following example:
# ['and the night of the eighteenth.', "So, you'll be checking out at noon on the nineteenth, and yes, I have good news for you, the gold room is actually available for the required days."]
# ['と18日の夜のことです。', 'つまり、19日の正午にチェックアウトすることになりますが、そうそう、良いニュースがあります！', 'ゴールドルームは実際に必要な日数分だけ利用できるのです。']
# ['と18日の夜のことだ。', 'つまり、19日の正午にチェックアウトすることになるけど、そうそう、良いニュースがある！', 'ゴールドルームは実際に必要な日数分だけ利用できる。']
# ['と18日の夜のことです。', 'つまり、19日の正午にチェックアウトすることになりますが、そうそう、[F]良いニュースがあります[/F]！', 'ゴールドルームは実際に必要な日数分だけ[F]利用できるのです[/F]。']
# ['と18日の夜のこと[F]だ[/F]。', 'つまり、19日の正午にチェックアウトすることに[F]なる[/F]けど、そうそう、良いニュースが[F]ある[/F]！', 'ゴールドルームは実際に必要な日数分だけ[F]利用できる[/F]。']
#
# Different number of sentences found in the following example:
# ['Wow!', "Yes, I mean, I want to give you my phone number, but I've had so much trouble in the past with telemarketers, prank calls"]
# ['はい、つまり、私の電話番号を教えたいのですが、過去に電話勧誘やいたずら電話で大変な思いをしたことがあります。']
# ['うわぁ！？', 'はい、つまり、私の電話番号を教えたいんだけど、過去に電話勧誘やいたずら電話で大変な思いをしたことがある。']
# ['はい、つまり、私の電話番号を[F]教えたいのです[/F]が、過去に電話勧誘やいたずら電話で大変な思いをしたことが[F]あります[/F]。']
# ['うわぁ！？', 'はい、つまり、私の電話番号を[F]教えたい[/F]んだけど、過去に電話勧誘やいたずら電話で大変な思いをしたことが[F]ある[/F]。']
#
# Different number of sentences found in the following example:
# ['Sure.', "I'll be glad to help you with all those details.", 'But first, I wanted your contact details.', 'Phone number and your email, please?']
# ['はい、喜んで手伝います。', 'その前に、あなたの連絡先を教えてください。', '電話番号とメールアドレスを教えてください。']
# ['はい、喜んで手伝いさせてもらう。', 'その前に、あなたの連絡先を教えて。', '電話番号とメールアドレスを教えて。']
# ['はい、喜んで[F]手伝います[/F]。', 'その前に、あなたの連絡先を[F]教えてください[/F]。', '電話番号とメールアドレスを[F]教えてください[/F]。']
# ['はい、喜んで手伝い[F]させて[/F]もらう。', 'その前に、あなたの連絡先を[F]教えて[/F]。', '電話番号とメールアドレスを教えて。']
#
# Different number of sentences found in the following example:
# ['first class.', "I'm gonna upgrade you guys.", "I'm gonna upgrade you guys to first class because I really like the way you talk to me, and the way everything was handled.", 'So, how does that sound?']
# ['のファーストクラスです。', '私はあなたたちをアップグレードします。', '私はあなた方をファーストクラスにアップグレードします。', 'あなた方の話し方や、すべての処理の仕方がとても丁寧だからです。', 'それで、どうでしょうか？']
# ['のファーストクラスだ。', '私はあなたたちをアップグレードする。', '私はあなた方をファーストクラスにアップグレードする。', 'あなた方の話し方や、すべての処理の仕方がとても丁寧だからです。', 'それで、どうだろう？']
# ['のファーストクラスです。', '私はあなたたちをアップグレードします。', '私はあなた方をファーストクラスにアップグレードします。', 'あなた方の話し方や、すべての処理の仕方がとても[F]丁寧だから[/F]です。', 'それで、[F]どうでしょう[/F]か？']
# ['のファーストクラスだ。', '私はあなたたちをアップグレードする。', '私はあなた方をファーストクラスにアップグレードする。', 'あなた方の話し方や、すべての処理の仕方がとても[F]丁寧だから[/F]です。', 'それで、どう[F]だろう[/F]？']
#
# Number of bad examples: 135

# %%
# write split texts into files
base_path = f"./formality/CoCoA-MT/{split}/{source_lang}-{target_lang}/"
source_file = f"formality-control.{split}.all.{source_lang}-{target_lang}.{source_lang}"
target_formal_file = f"formality-control.{split}.all.{source_lang}-{target_lang}.formal.{target_lang}"
target_formal_feminine_file = f"formality-control.{split}.all.{source_lang}-{target_lang}.formal.feminine.{target_lang}"
target_informal_file = f"formality-control.{split}.all.{source_lang}-{target_lang}.informal.{target_lang}"
target_informal_feminine_file = f"formality-control.{split}.all.{source_lang}-{target_lang}.informal.feminine.{target_lang}"
target_formal_tagged_file = f"formality-control.{split}.all.{source_lang}-{target_lang}.formal.annotated.{target_lang}"
target_informal_tagged_file = f"formality-control.{split}.all.{source_lang}-{target_lang}.informal.annotated.{target_lang}"

with open(base_path + source_file, "w") as f:
    for example in source_texts_new:
        if isinstance(example, list):
            f.write("\n".join(example) + "\n")
        else:
            f.write(example + "\n")
with open(base_path + target_formal_file, "w") as f:
    for example in target_texts_formal_new:
        if isinstance(example, list):
            f.write(example[0] + "\n")
        else:
            f.write(example + "\n")
with open(base_path + target_formal_feminine_file, "w") as f:
    for example in target_texts_formal_new:
        if isinstance(example, list):
            f.write(example[1] + "\n")

with open(base_path + target_informal_file, "w") as f:
    for example in target_texts_informal_new:
        if isinstance(example, list):
            f.write(example[0] + "\n")
        else:
            f.write(example + "\n")
with open(base_path + target_informal_feminine_file, "w") as f:
    for example in target_texts_informal_new:
        if isinstance(example, list):
            f.write(example[1] + "\n")

with open(base_path + target_formal_tagged_file, "w") as f:
    for example in target_texts_formal_tagged_new:
        if isinstance(example, list):
            f.write("\n".join(example) + "\n")
        else:
            f.write(example + "\n")
with open(base_path + target_informal_tagged_file, "w") as f:
    for example in target_texts_informal_tagged_new:
        if isinstance(example, list):
            f.write("\n".join(example) + "\n")
        else:
            f.write(example + "\n")
