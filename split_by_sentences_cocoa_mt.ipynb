# %%
from indicnlp.tokenize import sentence_tokenize as sentence_tokenize_indic
import hasami

source_lang = "en"
target_lang = "de"

sentencizer_source_language = "english"
sentencizer_target_language = "german"

split = "train"

if split == "train":
    domains = ["telephony", "topical_chat"]
elif split == "test":
    domains = ["telephony", "topical_chat", "call_center"]

# %%
from formality.data_loader import load_data

source_texts = []
target_texts_formal = []
target_texts_informal = []
target_texts_formal_tagged, target_texts_informal_tagged = [], []

for domain in domains:
    domain_source_texts, domain_target_texts_formal, _, _ = load_data(source_lang, target_lang, split, "all", "formal")
    domain_source_texts, domain_target_texts_informal, _, _ = load_data(source_lang, target_lang, split, "all", "informal")
    source_texts.extend(domain_source_texts)
    target_texts_formal.extend(domain_target_texts_formal)
    target_texts_informal.extend(domain_target_texts_informal)

    base_path = f"./formality/CoCoA-MT/{split}/{source_lang}-{target_lang}/"
    tagged_formal_path = f"formality-control.{split}.{domain}.{source_lang}-{target_lang}.formal.annotated"
    if target_lang != "ja" and split == "train":
        tagged_formal_path += f".{target_lang}"
    tagged_informal_path = f"formality-control.{split}.{domain}.{source_lang}-{target_lang}.informal.annotated"
    if target_lang != "ja" and split == "train":
        tagged_informal_path += f".{target_lang}"
    with open(base_path + tagged_formal_path, "r") as f:
        for line in f:
            target_texts_formal_tagged.append(line.strip())
    with open(base_path + tagged_informal_path, "r") as f:
        for line in f:
            target_texts_informal_tagged.append(line.strip())

# %%
len(source_texts)
# Out:
# 713

# %%
import re
FORMALITY_PHRASES = re.compile("(\[F\](.*?)\[/F\])")

count = 0
for text in target_texts_formal_tagged:
    if len(FORMALITY_PHRASES.findall(text)) > 1:
        count += 1

print(count)
# Out:
# 179

# %%
from nltk import tokenize

def split_into_sentences(text, sentencizer_language):
    if sentencizer_language == "hindi":
        sent_tokenize = lambda text : sentence_tokenize_indic.sentence_split(text, "hi")
    elif sentencizer_language == "japanese":
        sent_tokenize = hasami.segment_sentences
    else:
        sent_tokenize = lambda text : tokenize.sent_tokenize(text, sentencizer_language)
    if isinstance(text, list):
        sentencized_examples = []
        num_sentences = None
        for example in text:
            sentences = sent_tokenize(example)
            if isinstance(sentences, str):
                sentences = [sentences]
            sentencized_examples.append(sentences)
            if num_sentences is None:
                num_sentences = len(sentences)
            elif num_sentences != len(sentences):
                print("ERROR: Number of sentences in examples is not consistent.")
                print(text)
    
        return [[examples[i] for examples in sentencized_examples] for i in range(len(sentencized_examples[0]))]
    else:
        return sent_tokenize(text)

# %%
import re
FORMALITY_PHRASES = re.compile("(\[F\](.*?)\[/F\])")

source_texts_new, target_texts_formal_new, target_texts_informal_new = [], [], []
target_texts_formal_tagged_new, target_texts_informal_tagged_new = [], []
bad_examples = []
examples_with_no_formality_phrase = []
for source, target_formal, target_informal, tagged_formal, tagged_informal in zip(source_texts, target_texts_formal, target_texts_informal, target_texts_formal_tagged, target_texts_informal_tagged):
    source_sentences = split_into_sentences(source, sentencizer_source_language)
    target_formal_sentences = split_into_sentences(target_formal, sentencizer_target_language)
    target_informal_sentences = split_into_sentences(target_informal, sentencizer_target_language)
    tagged_formal_sentences = split_into_sentences(tagged_formal, sentencizer_target_language)
    tagged_informal_sentences = split_into_sentences(tagged_informal, sentencizer_target_language)

    indices_to_delete = []
    for i, tagged_formal_sentence in enumerate(tagged_formal_sentences):
        if len(re.findall(FORMALITY_PHRASES, tagged_formal_sentence)) == 0:
            print("No formality phrases found in the following example:", tagged_formal_sentence)
            indices_to_delete.append(i)    
    
    if len(source_sentences) == len(target_formal_sentences) == len(target_informal_sentences) == len(tagged_formal_sentences) == len(tagged_informal_sentences):
        for i in sorted(indices_to_delete, reverse=True):
            del source_sentences[i]
            del target_formal_sentences[i]
            del target_informal_sentences[i]
            del tagged_formal_sentences[i]
            del tagged_informal_sentences[i]
        
        if len(source_sentences) == 0:
            examples_with_no_formality_phrase.append((source, target_formal, target_informal, tagged_formal, tagged_informal))
            continue

        source_texts_new.extend(source_sentences)
        target_texts_formal_new.extend(target_formal_sentences)
        target_texts_informal_new.extend(target_informal_sentences)
        target_texts_formal_tagged_new.extend(tagged_formal_sentences)
        target_texts_informal_tagged_new.extend(tagged_informal_sentences)
    else:
        bad_examples.append((source_sentences, target_formal_sentences, target_informal_sentences, tagged_formal_sentences, tagged_informal_sentences))
        print("Different number of sentences found in the following example:")
        print(source_sentences)
        print(target_formal_sentences)
        print(target_informal_sentences)
        print(tagged_formal_sentences)
        print(tagged_informal_sentences)
        print()

print("Number of bad examples:", len(bad_examples))
print("Number of examples with no formality phrase:", len(examples_with_no_formality_phrase))
# Out:
# No formality phrases found in the following example: Es muss eine Kundenservice-Kultur sein und es muss für die Leute ein Erlebnis sein, anstatt einfach reinzukommen
# No formality phrases found in the following example: Weil das handgemacht ist oder, ich meine, es ist dazu gemacht, sich im Grunde innerhalb von einem Jahr zu zersetzen.
# No formality phrases found in the following example: Sie müssen das, das ist ihr Deal, sie müssen machen, es ist das Gleiche, das mit Home Depot passiert ist.
# No formality phrases found in the following example: Nein, auf dem Rückweg von Budapest hatte ich tatsächlich die Möglichkeit, als meine Oma noch lebte.
# No formality phrases found in the following example: Sie wuchs in Budapest auf.
# Different number of sentences found in the following example:
# ['No, going back from Budapest, I actually had the opportunity when my grandmother was still alive.']
# [['Nein, auf dem Rückweg von Budapest hatte ich tatsächlich die Möglichkeit, als meine Oma noch lebte.', 'Nein, auf dem Rückweg von Budapest hatte ich tatsächlich die Möglichkeit, als meine Oma noch lebte.']]
# [['Nein, auf dem Rückweg von Budapest hatte ich tatsächlich die Möglichkeit, als meine Oma noch lebte.', 'Nein, auf dem Rückweg von Budapest hatte ich tatsächlich die Möglichkeit, als meine Oma noch lebte.']]
# ['Nein, auf dem Rückweg von Budapest hatte ich tatsächlich die Möglichkeit, als meine Oma noch lebte.', 'Sie wuchs in Budapest auf.']
# ['Nein, auf dem Rückweg von Budapest hatte ich tatsächlich die Möglichkeit, als meine Oma noch lebte.', 'Sie wuchs in Budapest auf.']
#
# No formality phrases found in the following example: Ich werde einfach genau das machen, was mit mir gemacht wurde und all diese Dinge wurden in China gefertigt, ich höre hier einfach irgendwie auf.
# No formality phrases found in the following example: Meine Cousins im Süden unten, die passen immer auf, North Carolina, sie kommen nach New York, jeder liebt New York, ihre Familie will sehen
# No formality phrases found in the following example: Die Leute, die dort gearbeitet haben, kommen runter und irgendwelche Proben, die sie bekommen können, sie bringen sie einfach herunter.
# No formality phrases found in the following example: Ersetzt Amazon wirklich den Einzelhandel, ich weiß nicht, ich denke, ich akzeptiere ihre Einzelhandelsverbandskonferenz von den letzten Tagen.
# No formality phrases found in the following example: Das geht, aber sie würden die Art und Weise ändern müssen, die sie von Leuten, die in der Kosmetikabteilung arbeiten, auch erwarten.
# No formality phrases found in the following example: Weil es ist einfach krass, dass, wenn wir darüber nachdenken, es ist einfach wie
# No formality phrases found in the following example: Ich habe darüber nachgedacht und wie lächerlich das ist.
# Different number of sentences found in the following example:
# ['So how do you put the value of just the family and like, if you could think back on your life like how it is']
# [['Wie schätzen Sie dann den Wert der Familie ein und wie, wenn Sie an Ihr Leben zurückdenken könnten, wie es ist', 'Wie schätzen Sie dann den Wert der Familie ein und wie, wenn Sie an Ihr Leben zurückdenken könnten, wie es ist']]
# [['Wie schätzt du dann den Wert der Familie ein und wie, wenn du an dein Leben zurückdenken könntest, wie es ist', 'Wie schätzt du dann den Wert der Familie ein und wie, wenn du an dein Leben zurückdenken könntest, wie es ist']]
# ['das [F]waren Sie[/F], wir haben darüber gesprochen, dass jemand in [F]Ihrem[/F] Kurs für moderne Schauspielerei Casting-Direktor werden wollte und einen Backup-Job gebucht hat.', 'Ich habe darüber nachgedacht und wie lächerlich das ist.']
# ['das [F]warst du[/F], wir haben darüber gesprochen, dass jemand in [F]deinem[/F] Kurs für moderne Schauspielerei Casting-Direktor werden wollte und einen Backup-Job gebucht hat.', 'Ich habe darüber nachgedacht und wie lächerlich das ist.']
#
# No formality phrases found in the following example: Relativ bekannt, wie ein Fashion-Typ-Preis auch, sie sind echt gut darin, verschiedene T-Shirts und solche Dinge anzubieten.
# No formality phrases found in the following example: Das wäre Puerto Rico.
# Different number of sentences found in the following example:
# ['So, what is your ideal boyfriend?']
# [['Also, was ist Ihr idealer fester Freund?', 'Also, was ist Ihr idealer fester Freund?']]
# [['Also, was ist dein idealer fester Freund?', 'Also, was ist dein idealer fester Freund?']]
# ['Was war [F]Ihr[/F] letztes Zuhause?', 'Das wäre Puerto Rico.']
# ['Was war [F]dein[/F] letztes Zuhause?', 'Das wäre Puerto Rico.']
#
# No formality phrases found in the following example: Also, was bleibt noch übrig?
# Different number of sentences found in the following example:
# ['fairly known like a fashion type price too, they are really good providing different T-shirt that kind of stuff.']
# [['Relativ bekannt, wie ein Fashion-Typ-Preis auch, sie sind echt gut darin, verschiedene T-Shirts und solche Dinge anzubieten.', 'Relativ bekannt, wie ein Fashion-Typ-Preis auch, sie sind echt gut darin, verschiedene T-Shirts und solche Dinge anzubieten.']]
# [['Relativ bekannt, wie ein Fashion-Typ-Preis auch, sie sind echt gut darin, verschiedene T-Shirts und solche Dinge anzubieten.', 'Relativ bekannt, wie ein Fashion-Typ-Preis auch, sie sind echt gut darin, verschiedene T-Shirts und solche Dinge anzubieten.']]
# ['Es wird bei [F]Ihnen[/F] gesichert.', 'Also, was bleibt noch übrig?']
# ['Es wird bei [F]dir[/F] gesichert.', 'Also, was bleibt noch übrig?']
#
# No formality phrases found in the following example: So ist es.
# Different number of sentences found in the following example:
# ["it's backing up on yours."]
# [['Es wird bei Ihnen gesichert.', 'Es wird bei Ihnen gesichert.']]
# [['Es wird bei dir gesichert.', 'Es wird bei dir gesichert.']]
# ['Urgroßvater, [F]Sie wissen[/F], was ich meine.', 'So ist es.']
# ['Urgroßvater, [F]du weißt[/F], was ich meine.', 'So ist es.']
#
# No formality phrases found in the following example: Das tut mir leid, ja, und es ist sehr interessant.
# Different number of sentences found in the following example:
# ['I got a hundred colours in your city.']
# [['Ich habe in Ihrer Stadt einhundert Farben bekommen.', 'Ich habe in Ihrer Stadt einhundert Farben bekommen.']]
# [['Ich habe in deiner Stadt einhundert Farben bekommen.', 'Ich habe in deiner Stadt einhundert Farben bekommen.']]
# ['Das tut mir leid, ja, und es ist sehr interessant.', 'Wie war [F]Ihre[/F] Erfahrung mit Auslandsreisen?']
# ['Das tut mir leid, ja, und es ist sehr interessant.', 'Wie war [F]deine[/F] Erfahrung mit Auslandsreisen?']
#
# No formality phrases found in the following example: Wir durften das Gefühl von Wut zeigen, denn das war alles, was jemand je gezeigt hat,
# Different number of sentences found in the following example:
# ['What was your favorite Disney movie growing up?']
# [['Was war als Kind Ihr Lieblingsfilm von Disney?', 'Was war als Kind Ihr Lieblingsfilm von Disney?']]
# [['Was war als Kind dein Lieblingsfilm von Disney?', 'Was war als Kind dein Lieblingsfilm von Disney?']]
# ['Nun, Gefühle waren in [F]Ihrer[/F] Familie offensichtlich nicht erlaubt und sie waren auch in meiner Familie wirklich nicht erlaubt, es sei denn, es war Wut.', 'Wir durften das Gefühl von Wut zeigen, denn das war alles, was jemand je gezeigt hat,']
# ['Nun, Gefühle waren in [F]deiner[/F] Familie offensichtlich nicht erlaubt und sie waren auch in meiner Familie wirklich nicht erlaubt, es sei denn, es war Wut.', 'Wir durften das Gefühl von Wut zeigen, denn das war alles, was jemand je gezeigt hat,']
#
# No formality phrases found in the following example: Ja, genau.
# Different number of sentences found in the following example:
# ["Well feelings obviously weren't allowed in your family and just like they really weren't allowed in mine either unless they were anger."]
# [['Nun, Gefühle waren in Ihrer Familie offensichtlich nicht erlaubt und sie waren auch in meiner Familie wirklich nicht erlaubt, es sei denn, es war Wut.', 'Nun, Gefühle waren in Ihrer Familie offensichtlich nicht erlaubt und sie waren auch in meiner Familie wirklich nicht erlaubt, es sei denn, es war Wut.']]
# [['Nun, Gefühle waren in deiner Familie offensichtlich nicht erlaubt und sie waren auch in meiner Familie wirklich nicht erlaubt, es sei denn, es war Wut.', 'Nun, Gefühle waren in deiner Familie offensichtlich nicht erlaubt und sie waren auch in meiner Familie wirklich nicht erlaubt, es sei denn, es war Wut.']]
# ['Ja, genau.', 'Okay, jetzt werde ich auch in meinen Modeläden nachsehen, wo [F]kaufen Sie[/F] ein?']
# ['Ja, genau.', 'Okay, jetzt werde ich auch in meinen Modeläden nachsehen, wo [F]kaufst du[/F] ein?']
#
# Different number of sentences found in the following example:
# ["We were allowed to express the feeling of anger because that's all anybody ever expressed,"]
# [['Wir durften das Gefühl von Wut zeigen, denn das war alles, was jemand je gezeigt hat,', 'Wir durften das Gefühl von Wut zeigen, denn das war alles, was jemand je gezeigt hat,']]
# [['Wir durften das Gefühl von Wut zeigen, denn das war alles, was jemand je gezeigt hat,', 'Wir durften das Gefühl von Wut zeigen, denn das war alles, was jemand je gezeigt hat,']]
# ['Es ist wichtiger als Arbeit, es ist wichtiger als einen Job und eine Karriere zu haben, weil [F]Ihre[/F] Karriere wird zu Ende gehen, [F]Ihre[/F] Familie wird nicht zu Ende gehen.', '[F]Ihre[/F] Familie wird weitergehen, [F]Ihre[/F] Blutlinie wird weitergehen.']
# ['Es ist wichtiger als Arbeit, es ist wichtiger als einen Job und eine Karriere zu haben, weil [F]deine[/F] Karriere wird zu Ende gehen, [F]deine[/F] Familie wird nicht zu Ende gehen.', '[F]Deine[/F] Familie wird weitergehen, [F]deine[/F] Blutlinie wird weitergehen.']
#
# No formality phrases found in the following example: In Ordnung, die Zahlung wurde getätigt.
# Different number of sentences found in the following example:
# ["just having that net there, it's big community so family is your immediate family, then the people behind you,"]
# [['Einfach dieses Netz da haben, diese große Gemeinschaft, also Familie ist Ihre unmittelbare Familie, dann die Leute hinter Ihnen,', 'Einfach dieses Netz da haben, diese große Gemeinschaft, also Familie ist Ihre unmittelbare Familie, dann die Leute hinter Ihnen,']]
# [['Einfach dieses Netz da haben, diese große Gemeinschaft, also Familie ist deine unmittelbare Familie, dann die Leute hinter dir,', 'Einfach dieses Netz da haben, diese große Gemeinschaft, also Familie ist deine unmittelbare Familie, dann die Leute hinter dir,']]
# ['In Ordnung, die Zahlung wurde getätigt.', 'Danke, dass [F]Sie[/F] AMC gewählt [F]haben[/F], [F]genießen Sie Ihren[/F] Film.', '[F]Haben Sie[/F] viel Spaß.']
# ['In Ordnung, die Zahlung wurde getätigt.', 'Danke, dass [F]du[/F] AMC gewählt [F]hast[/F], [F]genieß deinen[/F] Film.', '[F]Hab[/F] viel Spaß.']
#
# No formality phrases found in the following example: Ich nehme an, dasselbe.
# Different number of sentences found in the following example:
# ["Like you know paying for all your insurance and trying to find gigs and taking gigs you don't wanna take"]
# [['Wie, Sie wissen schon, für Ihre gesamten Versicherungen zahlen und versuchen, Auftritte zu finden und Auftritte anzunehmen, die Sie nicht nehmen wollen.', 'Wie, Sie wissen schon, für Ihre gesamten Versicherungen zahlen und versuchen, Auftritte zu finden und Auftritte anzunehmen, die Sie nicht nehmen wollen.']]
# [['Wie, du weißt schon, für deine gesamten Versicherungen zahlen und versuchen, Auftritte zu finden und Auftritte anzunehmen, die du nicht nehmen willst.', 'Wie, du weißt schon, für deine gesamten Versicherungen zahlen und versuchen, Auftritte zu finden und Auftritte anzunehmen, die du nicht nehmen willst.']]
# ['Wer ist [F]Ihr[/F] Lieblingsschauspieler?', 'Ich nehme an, dasselbe.']
# ['Wer ist [F]dein[/F] Lieblingsschauspieler?', 'Ich nehme an, dasselbe.']
#
# No formality phrases found in the following example: Das ist nur so.
# Different number of sentences found in the following example:
# ['Your family keep going, your bloodline will keep going']
# [['Ihre Familie wird weitergehen, Ihre Blutlinie wird weitergehen.', 'Ihre Familie wird weitergehen, Ihre Blutlinie wird weitergehen.']]
# [['Deine Familie wird weitergehen, deine Blutlinie wird weitergehen.', 'Deine Familie wird weitergehen, deine Blutlinie wird weitergehen.']]
# ['Das ist nur so.', 'Was würden [F]Ihre[/F] Eltern sich wünschen, dass [F]Sie sind[/F]?']
# ['Das ist nur so.', 'Was würden [F]deine[/F] Eltern sich wünschen, dass [F]du bist[/F]?']
#
# No formality phrases found in the following example: Genau, sie haben dort einfach Glück und ihr Paket ist von irgendwoher.
# Different number of sentences found in the following example:
# ['Thanks for choosing AMC, enjoy your movie.']
# [['Danke, dass Sie AMC gewählt haben, genießen Sie Ihren Film.', 'Danke, dass Sie AMC gewählt haben, genießen Sie Ihren Film.']]
# [['Danke, dass du AMC gewählt hast, genieß deinen Film.', 'Danke, dass du AMC gewählt hast, genieß deinen Film.']]
# ['Also, dann fange ich einfach an und frage [F]Sie[/F].', 'Was ist [F]Ihr[/F] liebster Ort, an dem [F]Sie[/F] je gewesen [F]sind[/F]?']
# ['Also, dann fange ich einfach an und frage [F]dich[/F].', 'Was ist [F]dein[/F] liebster Ort, an dem [F]du[/F] je gewesen [F]bist[/F]?']
#
# No formality phrases found in the following example: Ja, es ist wirklich nervig.
# No formality phrases found in the following example: Und ich hoffe, dass es das für die Leute einfacher machen wird, zuzuhören.
# Different number of sentences found in the following example:
# ['Who is your favourite actor?']
# [['Wer ist Ihr Lieblingsschauspieler?', 'Wer ist Ihr Lieblingsschauspieler?']]
# [['Wer ist dein Lieblingsschauspieler?', 'Wer ist dein Lieblingsschauspieler?']]
# ['Ist [F]Ihr[/F] Fenster übrigens offen?', '[F]Können Sie[/F] es zumachen?', 'Ja, es ist wirklich nervig.', 'Und ich hoffe, dass es das für die Leute einfacher machen wird, zuzuhören.']
# ['Ist [F]dein[/F] Fenster übrigens offen?', '[F]Kannst du[/F] es zumachen?', 'Ja, es ist wirklich nervig.', 'Und ich hoffe, dass es das für die Leute einfacher machen wird, zuzuhören.']
#
# No formality phrases found in the following example: Ich habe dort ein Konto.
# Different number of sentences found in the following example:
# ['I guess, like the same thing.']
# [['Ich nehme an, dasselbe.', 'Ich nehme an, dasselbe.']]
# [['Ich nehme an, dasselbe.', 'Ich nehme an, dasselbe.']]
# ['Aber [F]Sie könnten[/F] wirklich alle von denen machen, freelancer.com.', 'Ich habe dort ein Konto.']
# ['Aber [F]du könntest[/F] wirklich alle von denen machen, freelancer.com.', 'Ich habe dort ein Konto.']
#
# Different number of sentences found in the following example:
# ['Do you have other favorite movies from this year or from your life?']
# [['Haben Sie andere Lieblingsfilme von diesem Jahr oder in Ihrem Leben?', 'Haben Sie andere Lieblingsfilme von diesem Jahr oder in Ihrem Leben?']]
# [['Hast du andere Lieblingsfilme von diesem Jahr oder in deinem Leben?', 'Hast du andere Lieblingsfilme von diesem Jahr oder in deinem Leben?']]
# ['Was ist [F]Ihr[/F] Favorit?', "[F]Mögen Sie[/F] Starbucks, [F]mögen Sie[/F] Dunkin's, wie steht es mit diesen Coffeeshop-Ketten?"]
# ['Was ist [F]dein[/F] Favorit?', "[F]Magst du[/F] Starbucks, [F]magst du[/F] Dunkin's, wie steht es mit diesen Coffeeshop-Ketten?"]
#
# No formality phrases found in the following example: Das zerstört es.
# Different number of sentences found in the following example:
# ["and so I'll just get it started by asking you this."]
# [['Also, dann fange ich einfach an und frage Sie.', 'Also, dann fange ich einfach an und frage Sie.']]
# [['Also, dann fange ich einfach an und frage dich.', 'Also, dann fange ich einfach an und frage dich.']]
# ['Also, deswegen funktioniert für mich Internet-TV manchmal nicht, weil ich kann nicht hören, wie [F]Sie[/F] Dinge [F]sagen[/F], nachdem es zehn Minuten vorher [F]Ihr[/F] Mund gesagt hat.', 'Das zerstört es.', 'Ich kann nicht verstehen, wie [F]Sie[/F] das [F]können[/F].']
# ['Also, deswegen funktioniert für mich Internet-TV manchmal nicht, weil ich kann nicht hören, wie [F]du[/F] Dinge [F]sagst[/F], nachdem es zehn Minuten vorher [F]dein[/F] Mund gesagt hat.', 'Das zerstört es.', 'Ich kann nicht verstehen, wie [F]du[/F] das [F]kannst[/F].']
#
# No formality phrases found in the following example: Ich weiß darüber nichts.
# Different number of sentences found in the following example:
# ['but any of those you could do, freelancer dot com.']
# [['Aber Sie könnten wirklich alle von denen machen, freelancer.com.', 'Aber Sie könnten wirklich alle von denen machen, freelancer.com.']]
# [['Aber du könntest wirklich alle von denen machen, freelancer.com.', 'Aber du könntest wirklich alle von denen machen, freelancer.com.']]
# ['Ich weiß darüber nichts.', 'Ich weiß nicht, ob [F]Ihnen[/F] das je passiert ist, ich meine, den Arm gebissen zu bekommen, das ist ziemlich einschneidend.']
# ['Ich weiß darüber nichts.', 'Ich weiß nicht, ob [F]dir[/F] das je passiert ist, ich meine, den Arm gebissen zu bekommen, das ist ziemlich einschneidend.']
#
# No formality phrases found in the following example: Wie was?
# Different number of sentences found in the following example:
# ['you never had any parties in your house.']
# [['Sie hatten nie irgendwelche Partys in Ihrem Haus.', 'Sie hatten nie irgendwelche Partys in Ihrem Haus.']]
# [['Du hattest nie irgendwelche Partys in deinem Haus.', 'Du hattest nie irgendwelche Partys in deinem Haus.']]
# ['Wie was?', '[F]Erzählen Sie[/F] mir, wie das Leben ist.', 'Und ich sagte ihm, [F]hören Sie[/F], das wird nicht funktionieren.', 'Und ich sagte, [F]tun Sie[/F] mir einen Gefallen.', '[F]Gehen Sie[/F] nicht zurück zu [F]Ihrem[/F]']
# ['Wie was?', '[F]Erzähl[/F] mir, wie das Leben ist.', 'Und ich sagte ihm, [F]hör[/F], das wird nicht funktionieren.', 'Und ich sagte, [F]tu[/F] mir einen Gefallen.', '[F]Geh[/F] nicht zurück zu [F]deinem[/F]']
#
# No formality phrases found in the following example: Ding zum Ausprobieren und den Preis herunterzubringen.
# Different number of sentences found in the following example:
# ["and they order all the products that they distribute that they're out of, you know brings the new things"]
# [['Und sie bestellen all die Produkte, die sie vertreiben und nicht vorrätig haben, wissen Sie, bringt die neuen Dinge', 'Und sie bestellen all die Produkte, die sie vertreiben und nicht vorrätig haben, wissen Sie, bringt die neuen Dinge']]
# [['Und sie bestellen all die Produkte, die sie vertreiben und nicht vorrätig haben, weißt du, bringt die neuen Dinge', 'Und sie bestellen all die Produkte, die sie vertreiben und nicht vorrätig haben, weißt du, bringt die neuen Dinge']]
# ['Ding zum Ausprobieren und den Preis herunterzubringen.', 'Weil für Airbnb sehe ich nicht allzu viele Coupons, also sie geben [F]Ihnen[/F] nicht [F]Ihr[/F] Geld, wenn ich']
# ['Ding zum Ausprobieren und den Preis herunterzubringen.', 'Weil für Airbnb sehe ich nicht allzu viele Coupons, also sie geben [F]dir[/F] nicht [F]dein[/F] Geld, wenn ich']
#
# No formality phrases found in the following example: Kunden, die ernsthaft an etwas interessiert sind, nicht jemand, der einfach versucht, umsonst geschminkt zu werden.
# Different number of sentences found in the following example:
# ['it was a fun trip, what are your fondest memories of that trip?']
# [['Es war ein lustiger Ausflug, was sind Ihre schönsten Erinnerungen von diesem Ausflug?', 'Es war ein lustiger Ausflug, was sind Ihre schönsten Erinnerungen von diesem Ausflug?']]
# [['Es war ein lustiger Ausflug, was sind deine schönsten Erinnerungen von diesem Ausflug?', 'Es war ein lustiger Ausflug, was sind deine schönsten Erinnerungen von diesem Ausflug?']]
# ['weil es das nicht ist, [F]Sie beanspruchen[/F] die Zeit von jemandem, der [F]Ihnen[/F] etwas verkaufen könnte.', 'Kunden, die ernsthaft an etwas interessiert sind, nicht jemand, der einfach versucht, umsonst geschminkt zu werden.']
# ['weil es das nicht ist, [F]du beanspruchst[/F] die Zeit von jemandem, der [F]dir[/F] etwas verkaufen könnte.', 'Kunden, die ernsthaft an etwas interessiert sind, nicht jemand, der einfach versucht, umsonst geschminkt zu werden.']
#
# No formality phrases found in the following example: Wie viele Jobs sind eigentlich so.
# Different number of sentences found in the following example:
# ['Did your family push back at all when you told them you were vegetarian?']
# [['Hatte Ihre Familie überhaupt Einwände, als Sie ihnen gesagt haben, dass Sie Vegetarier sind?', 'Hatte Ihre Familie überhaupt Einwände, als Sie ihnen gesagt haben, dass Sie Vegetarierin sind?']]
# [['Hatte deine Familie überhaupt Einwände, als du ihnen gesagt hast, dass du Vegetarier bist?', 'Hatte deine Familie überhaupt Einwände, als du ihnen gesagt hast, dass du Vegetarierin bist?']]
# ['Wie viele Jobs sind eigentlich so.', 'Also, mit jemandem, der sich seltsam und unwohl fühlt als [F]Ihr[/F] Chef?']
# ['Wie viele Jobs sind eigentlich so.', 'Also, mit jemandem, der sich seltsam und unwohl fühlt als [F]dein[/F] Chef?']
#
# Different number of sentences found in the following example:
# ['and having someone ring you up and throw in the bag for you, I mean they need to create a reason for the people that actually come into a store']
# [['und jemanden zu haben, der für Sie kassiert und Ihre Sachen einpackt, ich meine, sie müssen einen Grund für die Leute schaffen, die tatsächlich in einen Laden gehen.', 'und jemanden zu haben, der für Sie kassiert und Ihre Sachen einpackt, ich meine, sie müssen einen Grund für die Leute schaffen, die tatsächlich in einen Laden gehen.']]
# [['und jemanden zu haben, der für Sie kassiert und Ihre Sachen einpackt, ich meine, sie müssen einen Grund für die Leute schaffen, die tatsächlich in einen Laden gehen.', 'und jemanden zu haben, der für Sie kassiert und Ihre Sachen einpackt, ich meine, sie müssen einen Grund für die Leute schaffen, die tatsächlich in einen Laden gehen.']]
# ['[F]Haben Sie[/F] es geschafft?', '[F]Haben Sie[/F] es geschafft, [F]Ihr[/F] Telefon anzumelden?']
# ['[F]Hast du[/F] es geschafft?', '[F]Hast du[/F] es geschafft, [F]dein[/F] Telefon anzumelden?']
#
# No formality phrases found in the following example: aber das glaube ich.
# No formality phrases found in the following example: Ich meine, durch die Online-Kurse lernen sie nicht genug.
# No formality phrases found in the following example: Einige von ihnen haben noch nicht mal mit Online-Kursen angefangen.
# Different number of sentences found in the following example:
# ['Yeah, you gotta say, everybody got their own attitude, you know what I am saying everybody got their own style']
# [['Ja, Sie müssen sagen, jeder hat seine eigene Haltung, wissen Sie, was ich meine, jeder hat seinen eigenen Stil.', 'Ja, Sie müssen sagen, jeder hat seine eigene Haltung, wissen Sie, was ich meine, jeder hat seinen eigenen Stil.']]
# [['Ja, du musst sagen, jeder hat seine eigene Haltung, weißt du, was ich meine, jeder hat seinen eigenen Stil.', 'Ja, du musst sagen, jeder hat seine eigene Haltung, weißt du, was ich meine, jeder hat seinen eigenen Stil.']]
# ['aber das glaube ich.', 'Ich meine, durch die Online-Kurse lernen sie nicht genug.', 'Einige von ihnen haben noch nicht mal mit Online-Kursen angefangen.', 'Haben [F]Ihre[/F]?']
# ['aber das glaube ich.', 'Ich meine, durch die Online-Kurse lernen sie nicht genug.', 'Einige von ihnen haben noch nicht mal mit Online-Kursen angefangen.', 'Haben [F]deine[/F]?']
#
# Different number of sentences found in the following example:
# ['how much you pay for your internet bill?']
# [['Wie viel zahlen Sie für Ihre Internetrechnung?', 'Wie viel zahlen Sie für Ihre Internetrechnung?']]
# [['Wie viel zahlst du für deine Internetrechnung?', 'Wie viel zahlst du für deine Internetrechnung?']]
# ['Nein, ich sehe, dass [F]Ihrer[/F] groß und meiner fast flach ist.', 'Meine Lautstärke ist voll aufgedreht und [F]Sie kennen[/F] mein Mikrofon.']
# ['Nein, ich sehe, dass [F]deiner[/F] groß und meiner fast flach ist.', 'Meine Lautstärke ist voll aufgedreht und [F]du kennst[/F] mein Mikrofon.']
#
# No formality phrases found in the following example: Wie sieht es mit Elektronik aus?
# Different number of sentences found in the following example:
# ["you know, it's like fields trip field day, you know field day"]
# [['Wissen Sie, es ist wie eine Exkursion, der Ausflugstag, Sie kennen den Ausflugstag.', 'Wissen Sie, es ist wie eine Exkursion, der Ausflugstag, Sie kennen den Ausflugstag.']]
# [['Weißt du, es ist wie eine Exkursion, der Ausflugstag, du kennst den Ausflugstag.', 'Weißt du, es ist wie eine Exkursion, der Ausflugstag, du kennst den Ausflugstag.']]
# ['Wie sieht es mit Elektronik aus?', '[F]Finden Sie[/F], [F]Sie sind[/F] jemand, der elektronische Geräte kaufen muss?', '[F]Haben Sie[/F] in der letzten Zeit irgendwelche elektronischen Geräte gekauft?']
# ['Wie sieht es mit Elektronik aus?', '[F]Findest du[/F], [F]du bist[/F] jemand, der elektronische Geräte kaufen muss?', '[F]Hast du[/F] in der letzten Zeit irgendwelche elektronischen Geräte gekauft?']
#
# Different number of sentences found in the following example:
# ['Where do you stay on your trip across country?']
# [['Wo übernachten Sie während Ihrer Reise durch das Land?', 'Wo übernachten Sie während Ihrer Reise durch das Land?']]
# [['Wo übernachtest du während deiner Reise durch das Land?', 'Wo übernachtest du während deiner Reise durch das Land?']]
# ['[F]Wissen Sie[/F], was ich meine?', 'Ich weiß nicht, ob das wirklich [F]Ihre[/F] Frage beantwortet, aber das ist irgendwie eine augenöffnende Erfahrung für mich.']
# ['[F]Weißt du[/F], was ich meine?', 'Ich weiß nicht, ob das wirklich [F]deine[/F] Frage beantwortet, aber das ist irgendwie eine augenöffnende Erfahrung für mich.']
#
# No formality phrases found in the following example: Ich würde also versuchen, den ein bisschen zu erhöhen.
# Different number of sentences found in the following example:
# ["do you think you like your boyfriend's family?"]
# [['Denken Sie, Sie mögen die Familie Ihres Freundes?', 'Denken Sie, Sie mögen die Familie Ihres Freundes?']]
# [['Denkst du, du magst die Familie deines Freundes?', 'Denkst du, du magst die Familie deines Freundes?']]
# ['Also, das wird [F]Ihren[/F] Schuss ändern, aber wenn [F]Sie sagen[/F], dass [F]Ihr[/F] Schuss zu schwach ist, [F]haben Sie[/F] eventuell schon mal einen zu niedrigen TDS-Wert.', 'Ich würde also versuchen, den ein bisschen zu erhöhen.']
# ['Also, das wird [F]deinen[/F] Schuss ändern, aber wenn [F]du sagst[/F], dass [F]dein[/F] Schuss zu schwach ist, [F]hast du[/F] eventuell schon mal einen zu niedrigen TDS-Wert.', 'Ich würde also versuchen, den ein bisschen zu erhöhen.']
#
# Different number of sentences found in the following example:
# ["Like somebody who's weird and uncomfortable as your boss?"]
# [['Also, mit jemandem, der sich seltsam und unwohl fühlt als Ihr Chef?', 'Also, mit jemandem, der sich seltsam und unwohl fühlt als Ihr Chef?']]
# [['Also, mit jemandem, der sich seltsam und unwohl fühlt als dein Chef?', 'Also, mit jemandem, der sich seltsam und unwohl fühlt als dein Chef?']]
# ['[F]Sie wissen[/F], was ich meine, was auch immer [F]Sie[/F] machen [F]wollen[/F], [F]Sie könnten[/F] es machen.', 'Haben [F]Sie[/F] bei allem unterstützt, das [F]Sie[/F] machen [F]möchten[/F].']
# ['[F]Du weißt[/F], was ich meine, was auch immer [F]du[/F] machen [F]willst[/F], [F]du könntest[/F] es machen.', 'Haben [F]dich[/F] bei allem unterstützt, das [F]du[/F] machen [F]möchtest[/F].']
#
# No formality phrases found in the following example: Ja, ich habe eine Menge Cousins, all meine Tanten, meine Onkel.
# No formality phrases found in the following example: Ich habe mindestens fünfzig Cousins.
# Different number of sentences found in the following example:
# ['And they had a market just like your solution']
# [['Und sie hatten einen Markt, genau wie Ihre Lösung.', 'Und sie hatten einen Markt, genau wie Ihre Lösung.']]
# [['Und sie hatten einen Markt, genau wie deine Lösung.', 'Und sie hatten einen Markt, genau wie deine Lösung.']]
# ['Ja, ich habe eine Menge Cousins, all meine Tanten, meine Onkel.', 'Ich habe mindestens fünfzig Cousins.']
# ['Ja, ich habe eine Menge Cousins, all meine Tanten, meine Onkel.', 'Ich habe mindestens fünfzig Cousins.']
#
# No formality phrases found in the following example: Also in Bezug auf Hygiene gab es selbst in der Mall gute Toiletten.
# No formality phrases found in the following example: In Bezug auf Hygiene war es definitiv kein Problem, Toiletten im westlichen Stil.
# Different number of sentences found in the following example:
# ["I mean what such an incredible buy there, you know, chocolate-covered almonds with I don't know."]
# [['Ich meine, was für ein unglaublicher Kauf dort, wissen Sie, schokoladenumhüllte Mandeln mit, ich weiß nicht.', 'Ich meine, was für ein unglaublicher Kauf dort, wissen Sie, schokoladenumhüllte Mandeln mit, ich weiß nicht.']]
# [['Ich meine, was für ein unglaublicher Kauf dort, weißt du, schokoladenumhüllte Mandeln mit, ich weiß nicht.', 'Ich meine, was für ein unglaublicher Kauf dort, weißt du, schokoladenumhüllte Mandeln mit, ich weiß nicht.']]
# ['Also in Bezug auf Hygiene gab es selbst in der Mall gute Toiletten.', 'Es gibt dort extra Zeug, um [F]sich[/F] zu waschen, wenn [F]Sie[/F] zur Toilette [F]gehen[/F] und so.', 'In Bezug auf Hygiene war es definitiv kein Problem, Toiletten im westlichen Stil.']
# ['Also in Bezug auf Hygiene gab es selbst in der Mall gute Toiletten.', 'Es gibt dort extra Zeug, um [F]dich[/F] zu waschen, wenn [F]du[/F] zur Toilette [F]gehst[/F] und so.', 'In Bezug auf Hygiene war es definitiv kein Problem, Toiletten im westlichen Stil.']
#
# No formality phrases found in the following example: Das ist perfekt und einfach und süß und das ist es.
# No formality phrases found in the following example: Oh, das sagt es.
# No formality phrases found in the following example: Ich hoffe, es ist so.
# Different number of sentences found in the following example:
# ['So what about your team, you mentioned that you have a pretty good relationship with your co-workers.']
# [['Was ist mit Ihrem Team, Sie haben erwähnt, dass Sie ein ziemlich gutes Verhältnis zu Ihren Kollegen haben.', 'Was ist mit Ihrem Team, Sie haben erwähnt, dass Sie ein ziemlich gutes Verhältnis zu Ihren Kollegen haben.']]
# [['Was ist mit deinem Team, du hast erwähnt, dass du ein ziemlich gutes Verhältnis zu deinen Kollegen hast.', 'Was ist mit deinem Team, du hast erwähnt, dass du ein ziemlich gutes Verhältnis zu deinen Kollegen hast.']]
# ['Ich hoffe, dass ich [F]Ihr[/F] Land bald besuchen werde.', 'Das ist perfekt und einfach und süß und das ist es.', 'Oh, das sagt es.', 'Ich hoffe, es ist so.']
# ['Ich hoffe, dass ich [F]dein[/F] Land bald besuchen werde.', 'Das ist perfekt und einfach und süß und das ist es.', 'Oh, das sagt es.', 'Ich hoffe, es ist so.']
#
# Different number of sentences found in the following example:
# ["Information on your Instagram, I'm sure"]
# [['Informationen auf Ihrem Instagram, ich bin mir sicher', 'Informationen auf Ihrem Instagram, ich bin mir sicher']]
# [['Informationen auf deinem Instagram, ich bin mir sicher', 'Informationen auf deinem Instagram, ich bin mir sicher']]
# ['Also, wie auch immer, und selber, was ist [F]Ihr[/F] Lieblingskaufhaus?', '[F]Wissen Sie[/F] was ich meine, wir machen den ganzen Bereich.']
# ['Also, wie auch immer, und selber, was ist [F]dein[/F] Lieblingskaufhaus?', '[F]Weißt du[/F] was ich meine, wir machen den ganzen Bereich.']
#
# No formality phrases found in the following example: Das ist eine weitere Sache.
# Different number of sentences found in the following example:
# ['What is your ideal profession?']
# [['Was ist Ihr idealer Beruf?', 'Was ist Ihr idealer Beruf?']]
# [['Was ist dein idealer Beruf?', 'Was ist dein idealer Beruf?']]
# ['Das ist eine weitere Sache.', '[F]Sie müssen[/F] schnell reagieren können, da sie immer Dinge tun, die unerwartet sind.']
# ['Das ist eine weitere Sache.', '[F]Du musst[/F] schnell reagieren können, da sie immer Dinge tun, die unerwartet sind.']
#
# Different number of sentences found in the following example:
# ["When you do, when you have a child that you're responsible for, you got to get your ducks in a row."]
# [['Wenn Sie das tun, wenn Sie ein Kind haben, für das Sie verantwortlich sind, müssen Sie Ihre Angelegenheiten geordnet bekommen.', 'Wenn Sie das tun, wenn Sie ein Kind haben, für das Sie verantwortlich sind, müssen Sie Ihre Angelegenheiten geordnet bekommen.']]
# [['Wenn du das tust, wenn du ein Kind hast, für das du verantwortlich bist, musst du deine Angelegenheiten geordnet bekommen.', 'Wenn du das tust, wenn du ein Kind hast, für das du verantwortlich bist, musst du deine Angelegenheiten geordnet bekommen.']]
# ['[F]Wissen Sie[/F], was ich meine?', '[F]Ihre[/F] Mutter ist zum Beispiel eine nette Frau, die ich nicht einmal von der Charakterisierung in der Freundschaft kenne.']
# ['[F]Weißt du[/F], was ich meine?', '[F]Deine[/F] Mutter ist zum Beispiel eine nette Frau, die ich nicht einmal von der Charakterisierung in der Freundschaft kenne.']
#
# No formality phrases found in the following example: Es gibt da draußen definitiv solche Leute und das macht keinen Sinn.
# No formality phrases found in the following example: Es ist mehr so als würde ich an Aliens glauben.
# Different number of sentences found in the following example:
# ['but I think so.']
# [['aber das glaube ich.', 'aber das glaube ich.']]
# [['aber das glaube ich.', 'aber das glaube ich.']]
# ['Ja, aber das ist [F]Ihre[/F] Sicht auf den Film.', 'Es gibt da draußen definitiv solche Leute und das macht keinen Sinn.', 'Es ist mehr so als würde ich an Aliens glauben.']
# ['Ja, aber das ist [F]deine[/F] Sicht auf den Film.', 'Es gibt da draußen definitiv solche Leute und das macht keinen Sinn.', 'Es ist mehr so als würde ich an Aliens glauben.']
#
# No formality phrases found in the following example: Alle meine Schwestern sind aufs College gegangen, sie haben das College abgeschlossen, der ältere Bruder hat seinen (Master).
# No formality phrases found in the following example: Schule ist eine Familie.
# Different number of sentences found in the following example:
# ["I mean, they're not learning enough through the online classes."]
# [['Ich meine, durch die Online-Kurse lernen sie nicht genug.', 'Ich meine, durch die Online-Kurse lernen sie nicht genug.']]
# [['Ich meine, durch die Online-Kurse lernen sie nicht genug.', 'Ich meine, durch die Online-Kurse lernen sie nicht genug.']]
# ['Alle meine Schwestern sind aufs College gegangen, sie haben das College abgeschlossen, der ältere Bruder hat seinen (Master).', 'Schule ist eine Familie.', '([F]Sie müssen[/F]) zur Schule gehen.']
# ['Alle meine Schwestern sind aufs College gegangen, sie haben das College abgeschlossen, der ältere Bruder hat seinen (Master).', 'Schule ist eine Familie.', '([F]Du musst[/F]) zur Schule gehen.']
#
# No formality phrases found in the following example: Ja.
# Different number of sentences found in the following example:
# ["Some of them haven't even started online classes."]
# [['Einige von ihnen haben noch nicht mal mit Online-Kursen angefangen.', 'Einige von ihnen haben noch nicht mal mit Online-Kursen angefangen.']]
# [['Einige von ihnen haben noch nicht mal mit Online-Kursen angefangen.', 'Einige von ihnen haben noch nicht mal mit Online-Kursen angefangen.']]
# ['Ja.', 'Und besonders, wenn [F]Sie[/F] auch noch [F]lügen[/F] und dann absichtlich bei [F]Ihren[/F] Lügen erwischt [F]werden[/F].', 'Dann [F]machen Sie sich[/F] auch, [F]Sie wirken[/F] nicht schlau.']
# ['Ja.', 'Und besonders, wenn [F]du[/F] auch noch [F]lügst[/F] und dann absichtlich bei [F]deinen[/F] Lügen erwischt [F]wirst[/F].', 'Dann [F]machst du dich[/F] auch, [F]du wirkst[/F] nicht schlau.']
#
# No formality phrases found in the following example: Oh mein Gott!
# Different number of sentences found in the following example:
# ['I see, you stand like you are supposed to be married your whole little story, how you guys got together,']
# [['Ich verstehe, Sie stehen da, als ob Sie verheiratet sein sollten, Ihre ganze kleine Geschichte, wie Sie zusammengekommen sind,', 'Ich verstehe, Sie stehen da, als ob Sie verheiratet sein sollten, Ihre ganze kleine Geschichte, wie Sie zusammengekommen sind,']]
# [['Ich verstehe, du stehst da, als ob du verheiratet sein solltest, deine ganze kleine Geschichte, wie ihr zusammengekommen seid,', 'Ich verstehe, du stehst da, als ob du verheiratet sein solltest, deine ganze kleine Geschichte, wie ihr zusammengekommen seid,']]
# ['Oh mein Gott!', 'Warum [F]zahlen Sie[/F] so viel?']
# ['Oh mein Gott!', 'Warum [F]zahlst du[/F] so viel?']
#
# No formality phrases found in the following example: Eine wahrscheinliche Ausrede.
# Different number of sentences found in the following example:
# ['My volume is maxed and you know my microphone.']
# [['Meine Lautstärke ist voll aufgedreht und Sie kennen mein Mikrofon.', 'Meine Lautstärke ist voll aufgedreht und Sie kennen mein Mikrofon.']]
# [['Meine Lautstärke ist voll aufgedreht und du kennst mein Mikrofon.', 'Meine Lautstärke ist voll aufgedreht und du kennst mein Mikrofon.']]
# ['[F]Sie trainieren[/F] in der Arbeit.', 'Eine wahrscheinliche Ausrede.', '[F]Haben Sie[/F] je in [F]Ihrem[/F] Leben, gab es je einen Punkt, an dem [F]Sie[/F] regelmäßig trainiert [F]haben[/F]?']
# ['[F]Du trainierst[/F] in der Arbeit.', 'Eine wahrscheinliche Ausrede.', '[F]Hast du[/F] je in [F]deinem[/F] Leben, gab es je einen Punkt, an dem [F]du[/F] regelmäßig trainiert [F]hast[/F]?']
#
# Different number of sentences found in the following example:
# ['your mom always sounds so like']
# [['Ihre Mutter klingt immer so sehr wie', 'Ihre Mutter klingt immer so sehr wie']]
# [['Deine Mutter klingt immer so sehr wie', 'Deine Mutter klingt immer so sehr wie']]
# ['Klingt wie, [F]warten Sie[/F] mal.', 'Wie alt ist [F]Ihre[/F] Tochter?']
# ['Klingt wie, [F]warte[/F] mal.', 'Wie alt ist [F]deine[/F] Tochter?']
#
# No formality phrases found in the following example: Martin ist jedermanns Lieblingssendung.
# Different number of sentences found in the following example:
# ['Do you find yourself needing to buy electronics?']
# [['Finden Sie, Sie sind jemand, der elektronische Geräte kaufen muss?', 'Finden Sie, Sie sind jemand, der elektronische Geräte kaufen muss?']]
# [['Findest du, du bist jemand, der elektronische Geräte kaufen muss?', 'Findest du, du bist jemand, der elektronische Geräte kaufen muss?']]
# ['Martin ist jedermanns Lieblingssendung.', 'Warum ist es [F]Ihre[/F] Lieblingssendung, Martin?']
# ['Martin ist jedermanns Lieblingssendung.', 'Warum ist es [F]deine[/F] Lieblingssendung, Martin?']
#
# No formality phrases found in the following example: Airline, kann ich meine Reise absagen, ohne zu stornieren?
# Different number of sentences found in the following example:
# ['Have you bought any electronics recently?']
# [['Haben Sie in der letzten Zeit irgendwelche elektronischen Geräte gekauft?', 'Haben Sie in der letzten Zeit irgendwelche elektronischen Geräte gekauft?']]
# [['Hast du in der letzten Zeit irgendwelche elektronischen Geräte gekauft?', 'Hast du in der letzten Zeit irgendwelche elektronischen Geräte gekauft?']]
# ['Airline, kann ich meine Reise absagen, ohne zu stornieren?', 'Wie könnte eine Stornierung [F]Ihre[/F] Arbeit beeinflussen?', 'Stornierung, okay, [F]Sie möchten Ihre[/F] Reise stornieren?', 'Wenn [F]Sie Ihren[/F] Flug stornieren [F]möchten[/F], [F]können Sie[/F] uns per E-Mail oder Telefon kontaktieren.']
# ['Airline, kann ich meine Reise absagen, ohne zu stornieren?', 'Wie könnte eine Stornierung [F]deine[/F] Arbeit beeinflussen?', 'Stornierung, okay, [F]Du möchtest deine[/F] Reise stornieren?', 'Wenn [F]du deinen[/F] Flug stornieren [F]möchtest[/F], [F]kannst du[/F] uns per E-Mail oder Telefon kontaktieren.']
#
# No formality phrases found in the following example: Was ich sage.
# No formality phrases found in the following example: Leben ohne Sorgen.
# No formality phrases found in the following example: Meine Rede.
# Different number of sentences found in the following example:
# ['Do you know what I mean?']
# [['Wissen Sie, was ich meine?', 'Wissen Sie, was ich meine?']]
# [['Weißt du, was ich meine?', 'Weißt du, was ich meine?']]
# ['Was ich sage.', 'Gut leben, [F]Sie wissen[/F] schon.', 'Leben ohne Sorgen.', '[F]Sie wissen[/F], was ich meine.', 'Meine Rede.']
# ['Was ich sage.', 'Gut leben, [F]du weißt[/F] schon.', 'Leben ohne Sorgen.', '[F]Du weißt[/F], was ich meine.', 'Meine Rede.']
#
# No formality phrases found in the following example: Es hilft definitiv.
# Different number of sentences found in the following example:
# ["I dunno if that really answers your question, but that's sort of an eye-opening experience for me."]
# [['Ich weiß nicht, ob das wirklich Ihre Frage beantwortet, aber das ist irgendwie eine augenöffnende Erfahrung für mich.', 'Ich weiß nicht, ob das wirklich Ihre Frage beantwortet, aber das ist irgendwie eine augenöffnende Erfahrung für mich.']]
# [['Ich weiß nicht, ob das wirklich deine Frage beantwortet, aber das ist irgendwie eine augenöffnende Erfahrung für mich.', 'Ich weiß nicht, ob das wirklich deine Frage beantwortet, aber das ist irgendwie eine augenöffnende Erfahrung für mich.']]
# ['Ein Student an der Uni zu sein, [F]wissen Sie[/F], was ich meine?', 'Es hilft definitiv.', 'Es ist praktisch, ich meine, [F]Ihr[/F] Vollzeitstudent hat nicht wirklich ein Auto.']
# ['Ein Student an der Uni zu sein, [F]weißt du[/F], was ich meine?', 'Es hilft definitiv.', 'Es ist praktisch, ich meine, [F]dein[/F] Vollzeitstudent hat nicht wirklich ein Auto.']
#
# Different number of sentences found in the following example:
# ['What are your favorite movies what are your other favorite movies and/or your movies of the year?']
# [['Was sind Ihre Lieblingsfilme, was sind Ihre anderen Lieblingsfilme und/oder Ihre Lieblingsfilme von diesem Jahr?', 'Was sind Ihre Lieblingsfilme, was sind Ihre anderen Lieblingsfilme und/oder Ihre Lieblingsfilme von diesem Jahr?']]
# [['Was sind deine Lieblingsfilme, was sind deine anderen Lieblingsfilme und/oder deine Lieblingsfilme von diesem Jahr?', 'Was sind deine Lieblingsfilme, was sind deine anderen Lieblingsfilme und/oder deine Lieblingsfilme von diesem Jahr?']]
# ['[F]Sie brauchen[/F] ein Rückgrat, [F]Sie brauchen[/F] Geld.', '[F]Sie wissen[/F], was ich meine, [F]Sie müssen[/F] das Geld verdienen']
# ['[F]Du brauchst[/F] ein Rückgrat, [F]du brauchst[/F] Geld.', '[F]Du weißt[/F], was ich meine, [F]Du musst[/F] das Geld verdienen']
#
# Different number of sentences found in the following example:
# ['so that will change your shot, but if you are saying that your shot is underwhelming, you possibly have too low of a TDS to begin with.']
# [['Also, das wird Ihren Schuss ändern, aber wenn Sie sagen, dass Ihr Schuss zu schwach ist, haben Sie eventuell schon mal einen zu niedrigen TDS-Wert.', 'Also, das wird Ihren Schuss ändern, aber wenn Sie sagen, dass Ihr Schuss zu schwach ist, haben Sie eventuell schon mal einen zu niedrigen TDS-Wert.']]
# [['Also, das wird deinen Schuss ändern, aber wenn du sagst, dass dein Schuss zu schwach ist, hast du eventuell schon mal einen zu niedrigen TDS-Wert.', 'Also, das wird deinen Schuss ändern, aber wenn du sagst, dass dein Schuss zu schwach ist, hast du eventuell schon mal einen zu niedrigen TDS-Wert.']]
# ['Das schadet [F]Ihrem[/F] Magen, okay.', 'Ich denke, [F]Sie haben[/F] eine Laktoseintoleranz.']
# ['Das schadet [F]deinem[/F] Magen, okay.', 'Ich denke, [F]du hast[/F] eine Laktoseintoleranz.']
#
# No formality phrases found in the following example: Das sah vielleicht ein bisschen seltsam aus.
# Different number of sentences found in the following example:
# ['Do you have any favourite spots or favourite memories about some of that, you know, if you stayed in your hotel or whatever the case might be?']
# [['Haben Sie irgendwelche Lieblingsorte oder Lieblingserinnerungen von manchen dieser, wissen Sie, ob Sie in Ihrem Hotel geblieben sind oder was auch immer passiert sein mag?', 'Haben Sie irgendwelche Lieblingsorte oder Lieblingserinnerungen von manchen dieser, wissen Sie, ob Sie in Ihrem Hotel geblieben sind oder was auch immer passiert sein mag?']]
# [['Hast du irgendwelche Lieblingsorte oder Lieblingserinnerungen von manchen dieser, weißt du, ob du in deinem Hotel geblieben bist oder was auch immer passiert sein mag?', 'Hast du irgendwelche Lieblingsorte oder Lieblingserinnerungen von manchen dieser, weißt du, ob du in deinem Hotel geblieben bist oder was auch immer passiert sein mag?']]
# ['Ich denke, weil Menschen einfach bezüglich Arten, wie [F]Sie sagten[/F], (entwickelt) sind.', 'Das sah vielleicht ein bisschen seltsam aus.', '[F]Sie denken Ihr[/F]']
# ['Ich denke, weil Menschen einfach bezüglich Arten, wie [F]du sagtest[/F], (entwickelt) sind.', 'Das sah vielleicht ein bisschen seltsam aus.', '[F]Du denkst dein[/F]']
#
# No formality phrases found in the following example: Nun, ja, und der Versand ist auch einfach, gratis.
# Different number of sentences found in the following example:
# ['So we are going to be talking about families and stuff like that and you know all that']
# [['Also werden wir über Familien und sowas reden und Sie wissen schon, all das', 'Also werden wir über Familien und sowas reden und Sie wissen schon, all das']]
# [['Also werden wir über Familien und sowas reden und du weißt schon, all das', 'Also werden wir über Familien und sowas reden und du weißt schon, all das']]
# ['[F]Sie wissen[/F], was ich meine, ich finde, Familie ist einfach alles, was wir haben.', 'Das ist alles, was wir haben, die einzigen Leute, die auf [F]Sie[/F] aufpassen werden.']
# ['[F]Du weißt[/F], was ich meine, ich finde, Familie ist einfach alles, was wir haben.', 'Das ist alles, was wir haben, die einzigen Leute, die auf [F]dich[/F] aufpassen werden.']
#
# No formality phrases found in the following example: Ich denke nicht, dass da irgendetwas falsch daran ist.
# No formality phrases found in the following example: Und ich sage nicht, dass es
# Different number of sentences found in the following example:
# ['Provide you for everything you wanna do.']
# [['Haben Sie bei allem unterstützt, das Sie machen möchten.', 'Haben Sie bei allem unterstützt, das Sie machen möchten.']]
# [['Haben dich bei allem unterstützt, das du machen möchtest.', 'Haben dich bei allem unterstützt, das du machen möchtest.']]
# ['Ich denke nicht, dass da irgendetwas falsch daran ist.', 'Aber, wenn ich [F]Ihnen[/F] sagen würde, es schädigt die Wirtschaft, würde das [F]Ihre[/F] Meinung überhaupt ändern?', 'Und ich sage nicht, dass es']
# ['Ich denke nicht, dass da irgendetwas falsch daran ist.', 'Aber, wenn ich [F]dir[/F] sagen würde, es schädigt die Wirtschaft, würde das [F]deine[/F] Meinung überhaupt ändern?', 'Und ich sage nicht, dass es']
#
# No formality phrases found in the following example: Okay, entweder Familie oder Arbeit an erster Stelle.
# Different number of sentences found in the following example:
# ["So every case is kind of just like if you can figure out how to get your clients and that's you know"]
# [['Es geht also in allen Fällen irgendwie einfach darum, ob Sie herausfinden können, wie Sie Ihre Kunden bekommen und das ist, wissen Sie,', 'Es geht also in allen Fällen irgendwie einfach darum, ob Sie herausfinden können, wie Sie Ihre Kunden bekommen und das ist, wissen Sie,']]
# [['Es geht also in allen Fällen irgendwie einfach darum, ob du herausfinden kannst, wie du deine Kunden bekommst und das ist, weißt du,', 'Es geht also in allen Fällen irgendwie einfach darum, ob du herausfinden kannst, wie du deine Kunden bekommst und das ist, weißt du,']]
# ['[F]Wissen Sie[/F], [F]Sie können[/F] nicht, es ist so, dass das, was auf [F]Ihren[/F] Dokumenten steht, nicht genug ist, nein, das ist es nicht.', 'Okay, entweder Familie oder Arbeit an erster Stelle.']
# ['[F]Weißt du[/F], [F]du kannst[/F] nicht, es ist so, dass das, was auf [F]deinen[/F] Dokumenten steht, nicht genug ist, nein, das ist es nicht.', 'Okay, entweder Familie oder Arbeit an erster Stelle.']
#
# No formality phrases found in the following example: Sie wollen einfach sehen, warum nicht.
# Different number of sentences found in the following example:
# ['I hope to visit your country in the near future.']
# [['Ich hoffe, dass ich Ihr Land bald besuchen werde.', 'Ich hoffe, dass ich Ihr Land bald besuchen werde.']]
# ...
# ['What were your thoughts on Harry Truman?']
# [['Was waren Ihre Gedanken zu Harry Truman?', 'Was waren Ihre Gedanken zu Harry Truman?']]
# [['Was waren deine Gedanken zu Harry Truman?', 'Was waren deine Gedanken zu Harry Truman?']]
# ['Ja, in Buffalo gibt es nicht viel mehr zu tun, als ins Einkaufszentrum zu gehen!', 'Also, da [F]Sie[/F] noch keinen Cadillac [F]hatten[/F], welche anderen Autos [F]hatten Sie[/F] in [F]Ihrem[/F] Leben?']
# ['Ja, in Buffalo gibt es nicht viel mehr zu tun, als ins Einkaufszentrum zu gehen!', 'Also, da [F]du[/F] noch keinen Cadillac [F]hattest[/F], welche anderen Autos [F]hattest du[/F] in [F]deinem[/F] Leben?']
#
# No formality phrases found in the following example: Ich nicht, ich komme nicht ursprünglich aus den USA.
# Different number of sentences found in the following example:
# ['The sax is a great instrument.']
# [['Das Saxofon ist ein tolles Instrument.', 'Das Saxofon ist ein tolles Instrument.']]
# [['Das Saxofon ist ein tolles Instrument.', 'Das Saxofon ist ein tolles Instrument.']]
# ['[F]Haben Sie[/F] das Spiel schon einmal selbst gespielt?', 'Ich nicht, ich komme nicht ursprünglich aus den USA.']
# ['[F]Hast du[/F] das Spiel schon einmal selbst gespielt?', 'Ich nicht, ich komme nicht ursprünglich aus den USA.']
#
# No formality phrases found in the following example: Mir macht das Genre nicht allzu viel aus, solange es mich zum Lachen bringt.
# Different number of sentences found in the following example:
# ['your son will learn to appreciate music much more.']
# [['Ihr Sohn wird lernen, Musik viel mehr zu schätzen zu wissen.', 'Ihr Sohn wird lernen, Musik viel mehr zu schätzen zu wissen.']]
# [['Dein Sohn wird lernen, Musik viel mehr zu schätzen zu wissen.', 'Dein Sohn wird lernen, Musik viel mehr zu schätzen zu wissen.']]
# ['Mir macht das Genre nicht allzu viel aus, solange es mich zum Lachen bringt.', 'Wie [F]schauen Sie sich Ihre[/F] Filme an, auf dem Fernseher oder dem Computer?']
# ['Mir macht das Genre nicht allzu viel aus, solange es mich zum Lachen bringt.', 'Wie [F]schaust du deine[/F] Filme an, auf dem Fernseher oder dem Computer?']
#
# No formality phrases found in the following example: Könnten genauso gut ein Risiko eingehen.
# No formality phrases found in the following example: LeBron sieht diese Saison gut aus.
# No formality phrases found in the following example: Er ist so fokussiert.
# Different number of sentences found in the following example:
# ['anyway, great chat!']
# [['Wie dem auch sei, toller Chat!', 'Wie dem auch sei, toller Chat!']]
# [['Wie dem auch sei, toller Chat!', 'Wie dem auch sei, toller Chat!']]
# ['Könnten genauso gut ein Risiko eingehen.', 'LeBron sieht diese Saison gut aus.', 'Er ist so fokussiert.', 'Wer ist [F]Ihr[/F] Lieblingsspieler?']
# ['Könnten genauso gut ein Risiko eingehen.', 'LeBron sieht diese Saison gut aus.', 'Er ist so fokussiert.', 'Wer ist [F]dein[/F] Lieblingsspieler?']
#
# No formality phrases found in the following example: Ja, das ist cool LOL.
# Different number of sentences found in the following example:
# ['Thats neat.']
# [['Sauber.', 'Sauber.']]
# [['Sauber.', 'Sauber.']]
# ['Ja, das ist cool LOL.', 'Was [F]denken Sie[/F] darüber, dass Vin Diesel ein geheimes Drehbuch erhalten hat, in dem steht, was Groot in den Filmen tatsächlich sagt?']
# ['Ja, das ist cool LOL.', 'Was [F]denkst du[/F] darüber, dass Vin Diesel ein geheimes Drehbuch erhalten hat, in dem steht, was Groot in den Filmen tatsächlich sagt?']
#
# No formality phrases found in the following example: Oder eine andere Website?
# Different number of sentences found in the following example:
# ['The trunk of your car is called that because they used to have wooden trunks in the back']
# [['Der Kofferraum Ihres Autos wird so genannt, weil sie früher Truhen aus Holz hinten drin hatten.', 'Der Kofferraum Ihres Autos wird so genannt, weil sie früher Truhen aus Holz hinten drin hatten.']]
# [['Der Kofferraum deines Autos wird so genannt, weil sie früher Truhen aus Holz hinten drin hatten.', 'Der Kofferraum deines Autos wird so genannt, weil sie früher Truhen aus Holz hinten drin hatten.']]
# ['Das ist interessant, ich habe mich das immer gefragt, [F]verwenden Sie[/F] Google für [F]Ihre[/F] Suchen?', 'Oder eine andere Website?']
# ['Das ist interessant, ich habe mich das immer gefragt, [F]verwendest du[/F] Google für [F]deine[/F] Suchen?', 'Oder eine andere Website?']
#
# No formality phrases found in the following example: Meiner ist The Dark Knight.
# No formality phrases found in the following example: Ich habe gehört, dass Smallville ursprünglich davon handeln sollte, wie aus Bruce Wayne Batman wurde.
# No formality phrases found in the following example: Ich glaube, daraus wurde dann Gotham.
# Different number of sentences found in the following example:
# ['Ah, a fellow weeb.']
# [['Ah, ein Mit-Weeb.', 'Ah, ein Mit-Weeb.']]
# [['Ah, ein Mit-Weeb.', 'Ah, ein Mit-Weeb.']]
# ['Welcher ist [F]Ihr[/F] Lieblings-Batman-Film?', 'Meiner ist The Dark Knight.', 'Ich habe gehört, dass Smallville ursprünglich davon handeln sollte, wie aus Bruce Wayne Batman wurde.', 'Ich glaube, daraus wurde dann Gotham.']
# ['Welcher ist [F]dein[/F] Lieblings-Batman-Film?', 'Meiner ist The Dark Knight.', 'Ich habe gehört, dass Smallville ursprünglich davon handeln sollte, wie aus Bruce Wayne Batman wurde.', 'Ich glaube, daraus wurde dann Gotham.']
#
# No formality phrases found in the following example: Schön, ich auch!
# Different number of sentences found in the following example:
# ['What is your favorite anime?']
# [['Was ist Ihr Lieblings-Anime?', 'Was ist Ihr Lieblings-Anime?']]
# [['Was ist dein Lieblings-Anime?', 'Was ist dein Lieblings-Anime?']]
# ['Schön, ich auch!', 'Ich habe nie davon gehört, das wäre großartig, [F]verwenden Sie Ihr[/F] eigenes Auto oder einen Wagen?']
# ['Schön, ich auch!', 'Ich habe nie davon gehört, das wäre großartig, [F]verwendest du dein[/F] eigenes Auto oder einen Wagen?']
#
# No formality phrases found in the following example: Ich könnte mir das definitiv vorstellen.
# No formality phrases found in the following example: Jane McGonigal war die Game-Designerin hinter dieser Studie, ziemlich cool.
# Different number of sentences found in the following example:
# ['Mines probably Death Note of No Game No Life.']
# [['Meiner ist wohl Death Note oder No Game No Life.', 'Meiner ist wohl Death Note oder No Game No Life.']]
# [['Meiner ist wohl Death Note oder No Game No Life.', 'Meiner ist wohl Death Note oder No Game No Life.']]
# ['Ich könnte mir das definitiv vorstellen.', 'Welches waren [F]Ihre[/F] Lieblings-Videospiele?', 'Jane McGonigal war die Game-Designerin hinter dieser Studie, ziemlich cool.']
# ['Ich könnte mir das definitiv vorstellen.', 'Welches waren [F]deine[/F] Lieblings-Videospiele?', 'Jane McGonigal war die Game-Designerin hinter dieser Studie, ziemlich cool.']
#
# No formality phrases found in the following example: Ja.
# No formality phrases found in the following example: Ja, das tue ich, als ich jünger war, habe ich viel Nintendo gespielt.
# Different number of sentences found in the following example:
# ['!When you watch Netflix on your computer, understand Captcha is an acronym for "completely automated public Turing test to tell computers and humans apart"']
# [['Wenn Sie auf Ihrem Computer Netflix schauen, sollten Sie wissen, dass Captcha ein Akronym für „completely automated public Turing test to tell computers and humans apart“ ist.', 'Wenn Sie auf Ihrem Computer Netflix schauen, sollten Sie wissen, dass Captcha ein Akronym für „completely automated public Turing test to tell computers and humans apart“ ist.']]
# [['Wenn du auf deinem Computer Netflix schaust, solltest du wissen, dass Captcha ein Akronym für „completely automated public Turing test to tell computers and humans apart“ ist.', 'Wenn du auf deinem Computer Netflix schaust, solltest du wissen, dass Captcha ein Akronym für „completely automated public Turing test to tell computers and humans apart“ ist.']]
# ['Ja, das tue ich, als ich jünger war, habe ich viel Nintendo gespielt.', 'Wie stehts mit [F]Ihnen[/F]?']
# ['Ja, das tue ich, als ich jünger war, habe ich viel Nintendo gespielt.', 'Wie stehts mit [F]dir[/F]?']
#
# No formality phrases found in the following example: Hier auch.
# Different number of sentences found in the following example:
# ['They could be in your attic if it is not well ventilated.']
# [['Sie könnten auf Ihrem Dachboden sein, wenn er nicht gut belüftet ist.', 'Sie könnten auf Ihrem Dachboden sein, wenn er nicht gut belüftet ist.']]
# [['Sie könnten auf deinem Dachboden sein, wenn er nicht gut belüftet ist.', 'Sie könnten auf deinem Dachboden sein, wenn er nicht gut belüftet ist.']]
# ['Hier auch.', '[F]Versuchen Sie[/F], den heutigen Tag zu [F]Ihrem[/F] perfekten Tag zu machen, wie auch immer der aussieht.']
# ['Hier auch.', '[F]Versuche[/F], den heutigen Tag zu [F]deinem[/F] perfekten Tag zu machen, wie auch immer der aussieht.']
#
# No formality phrases found in the following example: Das muss ein außergewöhnliches Spektakel sein, ihm beim Fressen zuzusehen.
# No formality phrases found in the following example: LOL.
# Different number of sentences found in the following example:
# ['wow.']
# [['Wow.', 'Wow.']]
# [['Wow.', 'Wow.']]
# ['Das muss ein außergewöhnliches Spektakel sein, ihm beim Fressen zuzusehen.', 'Eine gute Art, [F]Ihre[/F] Feinde loszuwerden!', 'LOL.']
# ['Das muss ein außergewöhnliches Spektakel sein, ihm beim Fressen zuzusehen.', 'Eine gute Art, [F]deine[/F] Feinde loszuwerden!', 'LOL.']
#
# No formality phrases found in the following example: Interessant.
# No formality phrases found in the following example: Ich habe ihn gesehen.
# Different number of sentences found in the following example:
# ['Hi there.']
# [['Hallo.', 'Hallo.']]
# [['Hallo.', 'Hallo.']]
# ['Interessant.', '[F]Haben Sie[/F] den Film gesehen?', 'Ich habe ihn gesehen.']
# ['Interessant.', '[F]Hast du[/F] den Film gesehen?', 'Ich habe ihn gesehen.']
#
# No formality phrases found in the following example: Stimmt.
# Different number of sentences found in the following example:
# ['Have you heard of the Razzie Awards?']
# [['Haben Sie von der Preisverleihung der Goldenen Himbeere gehört?', 'Haben Sie von der Preisverleihung der Goldenen Himbeere gehört?']]
# [['Hast du von der Preisverleihung der Goldenen Himbeere gehört?', 'Hast du von der Preisverleihung der Goldenen Himbeere gehört?']]
# ['Stimmt.', '[F]Haben Sie[/F] vor, den aktuellen Teil, Mission: Impossible – Fallout zu sehen?']
# ['Stimmt.', '[F]Hast du[/F] vor, den aktuellen Teil, Mission: Impossible – Fallout zu sehen?']
#
# No formality phrases found in the following example: Ich kenne ein paar, er hat zum Beispiel bei Bubba Gump gearbeitet.
# Different number of sentences found in the following example:
# ['yeah, it is a silly look.']
# [['Ja, es sieht lächerlich aus.', 'Ja, es sieht lächerlich aus.']]
# [['Ja, es sieht lächerlich aus.', 'Ja, es sieht lächerlich aus.']]
# ['Ich kenne ein paar, er hat zum Beispiel bei Bubba Gump gearbeitet.', 'War nett, mit [F]Ihnen[/F] zu chatten!']
# ['Ich kenne ein paar, er hat zum Beispiel bei Bubba Gump gearbeitet.', 'War nett, mit [F]dir[/F] zu chatten!']
#
# Different number of sentences found in the following example:
# ['nobody wants to see your drawers.']
# [['Niemand will Ihre Schubladen sehen.', 'Niemand will Ihre Schubladen sehen.']]
# [['Niemand will deine Schubladen sehen.', 'Niemand will deine Schubladen sehen.']]
# ['Hi, mir geht es super, und [F]Ihnen[/F]?', '[F]Lesen Sie[/F] gern?']
# ['Hi, mir geht es super, und [F]dir[/F]?', '[F]Liest du[/F] gern?']
#
# No formality phrases found in the following example: Ja.
# No formality phrases found in the following example: Das kommt mir jung vor.
# Different number of sentences found in the following example:
# ['Have a good night!']
# [['Haben Sie einen guten Abend!', 'Haben Sie einen guten Abend!']]
# [['Hab einen guten Abend!', 'Hab einen guten Abend!']]
# ['Ja.', 'Das kommt mir jung vor.', 'Nett, mit [F]Ihnen[/F] zu chatten!']
# ['Ja.', 'Das kommt mir jung vor.', 'Nett, mit [F]dir[/F] zu chatten!']
#
# No formality phrases found in the following example: Ich mochte sie in Die Schöne und das Biest.
# No formality phrases found in the following example: Bringt Kindheitserinnerungen zurück.
# Different number of sentences found in the following example:
# ["That's a good question, never thought about that."]
# [['Das ist eine gute Frage, habe nie darüber nachgedacht.', 'Das ist eine gute Frage, habe nie darüber nachgedacht.']]
# [['Das ist eine gute Frage, habe nie darüber nachgedacht.', 'Das ist eine gute Frage, habe nie darüber nachgedacht.']]
# ['Ich mochte sie in Die Schöne und das Biest.', 'Er ist auf Netflix, wenn [F]Sie[/F] darauf Zugriff [F]haben[/F].', 'Bringt Kindheitserinnerungen zurück.']
# ['Ich mochte sie in Die Schöne und das Biest.', 'Er ist auf Netflix, wenn [F]du[/F] darauf Zugriff [F]hast[/F].', 'Bringt Kindheitserinnerungen zurück.']
#
# No formality phrases found in the following example: Mir macht das Spaß.
# No formality phrases found in the following example: Das Spiel ist beim Zuschauen so unterhaltsam und schnell.
# Different number of sentences found in the following example:
# ["How would you exactly explain your job seriously to people, yeah, I'm just here in case aliens ever contact us."]
# [['Wie genau würden Sie Ihren Beruf anderen ernsthaft erklären, ja, ich bin nur für den Fall hier, dass uns Außerirdische kontaktieren.', 'Wie genau würden Sie Ihren Beruf anderen ernsthaft erklären, ja, ich bin nur für den Fall hier, dass uns Außerirdische kontaktieren.']]
# [['Wie genau würdest du deinen Beruf anderen ernsthaft erklären, ja, ich bin nur für den Fall hier, dass uns Außerirdische kontaktieren.', 'Wie genau würdest du deinen Beruf anderen ernsthaft erklären, ja, ich bin nur für den Fall hier, dass uns Außerirdische kontaktieren.']]
# ['Mir macht das Spaß.', 'Das Spiel ist beim Zuschauen so unterhaltsam und schnell.', 'Gefällt es [F]Ihnen[/F]?']
# ['Mir macht das Spaß.', 'Das Spiel ist beim Zuschauen so unterhaltsam und schnell.', 'Gefällt es [F]dir[/F]?']
#
# No formality phrases found in the following example: Die meisten Menschen denken, dass alle Haie Killerhaie sind, aber ich habe gelesen, dass nicht alle Haie Killerhaie sind.
# Different number of sentences found in the following example:
# ['I know what you mean.']
# [['Ich weiß, was Sie meinen.', 'Ich weiß, was Sie meinen.']]
# [['Ich weiß, was du meinst.', 'Ich weiß, was du meinst.']]
# ['Die meisten Menschen denken, dass alle Haie Killerhaie sind, aber ich habe gelesen, dass nicht alle Haie Killerhaie sind.', 'Aber [F]haben Sie[/F] die Filme über Haie gesehen?']
# ['Die meisten Menschen denken, dass alle Haie Killerhaie sind, aber ich habe gelesen, dass nicht alle Haie Killerhaie sind.', 'Aber [F]hast du[/F] die Filme über Haie gesehen?']
#
# No formality phrases found in the following example: Guten Morgen!
# Different number of sentences found in the following example:
# ['It is the only object known to have life and we need to know why that is.']
# [['Es ist das einzige Objekt, das nachweislich lebt, und wir müssen wissen, warum das so ist.', 'Es ist das einzige Objekt, das nachweislich lebt, und wir müssen wissen, warum das so ist.']]
# [['Es ist das einzige Objekt, das nachweislich lebt, und wir müssen wissen, warum das so ist.', 'Es ist das einzige Objekt, das nachweislich lebt, und wir müssen wissen, warum das so ist.']]
# ['Guten Morgen!', '[F]Haben Sie[/F] schon einmal von K-Pop gehört?']
# ['Guten Morgen!', '[F]Hast du[/F] schon einmal von K-Pop gehört?']
#
# No formality phrases found in the following example: Ich habe seit längerem keinen Disney-Film mehr gesehen.
# Different number of sentences found in the following example:
# ['That is a long time ago!']
# [['Das ist schon lange her!', 'Das ist schon lange her!']]
# [['Das ist schon lange her!', 'Das ist schon lange her!']]
# ['Ich habe seit längerem keinen Disney-Film mehr gesehen.', '[F]Haben Sie[/F] eine Empfehlung?']
# ['Ich habe seit längerem keinen Disney-Film mehr gesehen.', '[F]Hast du[/F] eine Empfehlung?']
#
# Number of bad examples: 240
# Number of examples with no formality phrase: 15

# %%
# write split texts into files
base_path = f"./formality/CoCoA-MT/{split}/{source_lang}-{target_lang}/"
source_file = f"formality-control.{split}.only_with_formality.{source_lang}-{target_lang}.{source_lang}"
target_formal_file = f"formality-control.{split}.only_with_formality.{source_lang}-{target_lang}.formal.{target_lang}"
target_formal_feminine_file = f"formality-control.{split}.only_with_formality.{source_lang}-{target_lang}.formal.feminine.{target_lang}"
target_informal_file = f"formality-control.{split}.only_with_formality.{source_lang}-{target_lang}.informal.{target_lang}"
target_informal_feminine_file = f"formality-control.{split}.only_with_formality.{source_lang}-{target_lang}.informal.feminine.{target_lang}"
target_formal_tagged_file = f"formality-control.{split}.only_with_formality.{source_lang}-{target_lang}.formal.annotated.{target_lang}"
target_informal_tagged_file = f"formality-control.{split}.only_with_formality.{source_lang}-{target_lang}.informal.annotated.{target_lang}"

with open(base_path + source_file, "w") as f:
    for example in source_texts_new:
        if isinstance(example, list):
            f.write("\n".join(example) + "\n")
        else:
            f.write(example + "\n")
with open(base_path + target_formal_file, "w") as f:
    for example in target_texts_formal_new:
        if isinstance(example, list):
            f.write(example[0] + "\n")
        else:
            f.write(example + "\n")
with open(base_path + target_formal_feminine_file, "w") as f:
    for example in target_texts_formal_new:
        if isinstance(example, list):
            f.write(example[1] + "\n")

with open(base_path + target_informal_file, "w") as f:
    for example in target_texts_informal_new:
        if isinstance(example, list):
            f.write(example[0] + "\n")
        else:
            f.write(example + "\n")
with open(base_path + target_informal_feminine_file, "w") as f:
    for example in target_texts_informal_new:
        if isinstance(example, list):
            f.write(example[1] + "\n")

with open(base_path + target_formal_tagged_file, "w") as f:
    for example in target_texts_formal_tagged_new:
        if isinstance(example, list):
            f.write("\n".join(example) + "\n")
        else:
            f.write(example + "\n")
with open(base_path + target_informal_tagged_file, "w") as f:
    for example in target_texts_informal_tagged_new:
        if isinstance(example, list):
            f.write("\n".join(example) + "\n")
        else:
            f.write(example + "\n")
